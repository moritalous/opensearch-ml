# %% [markdown]
# ---
# ## OpenSearch 起動・停止

# %% [markdown]
# * 起動

# %%
# %%bash
# docker compose -f "../0_opensearch-docker/docker-compose.yml" up -d
# Out:
#  Container opensearch-dashboards  Created
#  Container opensearch-node1  Created
#  Container opensearch-dashboards  Starting
#  Container opensearch-node1  Starting
#  Container opensearch-dashboards  Started
#  Container opensearch-node1  Started

# %% [markdown]
# * 停止

# %%
# %%bash
# docker compose -f "../0_opensearch-docker/docker-compose.yml" down
# # docker compose -f "../0_opensearch-docker/docker-compose.yml" down -v
# Out:
#  Container opensearch-node1  Stopping
#  Container opensearch-dashboards  Stopping
#  Container opensearch-dashboards  Stopped
#  Container opensearch-dashboards  Removing
#  Container opensearch-dashboards  Removed
#  Container opensearch-node1  Stopped
#  Container opensearch-node1  Removing
#  Container opensearch-node1  Removed
#  Network 0_opensearch-docker_opensearch-net  Removing
#  Network 0_opensearch-docker_opensearch-net  Removed

# %%
# %%bash
# docker compose -f "../0_opensearch-docker/docker-compose.yml" logs
# Out:
# opensearch-node1  | Disabling execution of install_demo_configuration.sh for OpenSearch Security Plugin
# opensearch-node1  | Disabling OpenSearch Security Plugin
# opensearch-node1  | Enabling execution of OPENSEARCH_HOME/bin/opensearch-performance-analyzer/performance-analyzer-agent-cli for OpenSearch Performance Analyzer Plugin
# opensearch-node1  | WARNING: A terminally deprecated method in java.lang.System has been called
# opensearch-node1  | WARNING: System::setSecurityManager has been called by org.opensearch.bootstrap.OpenSearch (file:/usr/share/opensearch/lib/opensearch-2.11.0.jar)
# opensearch-node1  | WARNING: Please consider reporting this to the maintainers of org.opensearch.bootstrap.OpenSearch
# opensearch-node1  | WARNING: System::setSecurityManager will be removed in a future release
# opensearch-node1  | WARNING: A terminally deprecated method in java.lang.System has been called
# opensearch-node1  | WARNING: System::setSecurityManager has been called by org.opensearch.bootstrap.Security (file:/usr/share/opensearch/lib/opensearch-2.11.0.jar)
# opensearch-node1  | WARNING: Please consider reporting this to the maintainers of org.opensearch.bootstrap.Security
# opensearch-node1  | WARNING: System::setSecurityManager will be removed in a future release
# opensearch-node1  | [2023-11-16T13:05:31,402][INFO ][o.o.n.Node               ] [67e1a2061aa1] version[2.11.0], pid[10], build[tar/4dcad6dd1fd45b6bd91f041a041829c8687278fa/2023-10-13T02:55:55.511945994Z], OS[Linux/5.15.123.1-microsoft-standard-WSL2/amd64], JVM[Eclipse Adoptium/OpenJDK 64-Bit Server VM/17.0.8/17.0.8+7]
# opensearch-node1  | [2023-11-16T13:05:31,404][INFO ][o.o.n.Node               ] [67e1a2061aa1] JVM home [/usr/share/opensearch/jdk], using bundled JDK/JRE [true]
# opensearch-node1  | [2023-11-16T13:05:31,404][INFO ][o.o.n.Node               ] [67e1a2061aa1] JVM arguments [-Xshare:auto, -Dopensearch.networkaddress.cache.ttl=60, -Dopensearch.networkaddress.cache.negative.ttl=10, -XX:+AlwaysPreTouch, -Xss1m, -Djava.awt.headless=true, -Dfile.encoding=UTF-8, -Djna.nosys=true, -XX:-OmitStackTraceInFastThrow, -XX:+ShowCodeDetailsInExceptionMessages, -Dio.netty.noUnsafe=true, -Dio.netty.noKeySetOptimization=true, -Dio.netty.recycler.maxCapacityPerThread=0, -Dio.netty.allocator.numDirectArenas=0, -Dlog4j.shutdownHookEnabled=false, -Dlog4j2.disable.jmx=true, -Djava.locale.providers=SPI,COMPAT, -Xms1g, -Xmx1g, -XX:+UseG1GC, -XX:G1ReservePercent=25, -XX:InitiatingHeapOccupancyPercent=30, -Djava.io.tmpdir=/tmp/opensearch-5606742270379846535, -XX:+HeapDumpOnOutOfMemoryError, -XX:HeapDumpPath=data, -XX:ErrorFile=logs/hs_err_pid%p.log, -Xlog:gc*,gc+age=trace,safepoint:file=logs/gc.log:utctime,pid,tags:filecount=32,filesize=64m, -Djava.util.concurrent.ForkJoinPool.common.threadFactory=org.opensearch.secure_sm.SecuredForkJoinWorkerThreadFactory, -Dclk.tck=100, -Djdk.attach.allowAttachSelf=true, -Djava.security.policy=/usr/share/opensearch/config/opensearch-performance-analyzer/opensearch_security.policy, --add-opens=jdk.attach/sun.tools.attach=ALL-UNNAMED, -Dopensearch.cgroups.hierarchy.override=/, -Xms512m, -Xmx512m, -XX:MaxDirectMemorySize=268435456, -Dopensearch.path.home=/usr/share/opensearch, -Dopensearch.path.conf=/usr/share/opensearch/config, -Dopensearch.distribution.type=tar, -Dopensearch.bundled_jdk=true]
# opensearch-node1  | [2023-11-16T13:05:33,068][INFO ][o.o.s.s.t.SSLConfig      ] [67e1a2061aa1] SSL dual mode is disabled
# opensearch-node1  | [2023-11-16T13:05:33,069][WARN ][o.o.s.OpenSearchSecurityPlugin] [67e1a2061aa1] OpenSearch Security plugin installed but disabled. This can expose your configuration (including passwords) to the public.
# opensearch-node1  | [2023-11-16T13:05:33,996][INFO ][o.o.p.c.c.PluginSettings ] [67e1a2061aa1] Config: metricsLocation: /dev/shm/performanceanalyzer/, metricsDeletionInterval: 1, httpsEnabled: false, cleanup-metrics-db-files: true, batch-metrics-retention-period-minutes: 7, rpc-port: 9650, webservice-port 9600
# opensearch-node1  | [2023-11-16T13:05:35,144][INFO ][o.o.i.r.ReindexPlugin    ] [67e1a2061aa1] ReindexPlugin reloadSPI called
# opensearch-node1  | [2023-11-16T13:05:35,145][INFO ][o.o.i.r.ReindexPlugin    ] [67e1a2061aa1] Unable to find any implementation for RemoteReindexExtension
# opensearch-node1  | [2023-11-16T13:05:35,184][INFO ][o.o.j.JobSchedulerPlugin ] [67e1a2061aa1] Loaded scheduler extension: opendistro_anomaly_detector, index: .opendistro-anomaly-detector-jobs
# opensearch-node1  | [2023-11-16T13:05:35,216][INFO ][o.o.j.JobSchedulerPlugin ] [67e1a2061aa1] Loaded scheduler extension: reports-scheduler, index: .opendistro-reports-definitions
# opensearch-node1  | [2023-11-16T13:05:35,220][INFO ][o.o.j.JobSchedulerPlugin ] [67e1a2061aa1] Loaded scheduler extension: opendistro-index-management, index: .opendistro-ism-config
# opensearch-node1  | [2023-11-16T13:05:35,221][INFO ][o.o.j.JobSchedulerPlugin ] [67e1a2061aa1] Loaded scheduler extension: scheduler_geospatial_ip2geo_datasource, index: .scheduler-geospatial-ip2geo-datasource
# opensearch-node1  | [2023-11-16T13:05:35,228][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [aggs-matrix-stats]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [analysis-common]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [geo]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [ingest-common]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [ingest-geoip]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [ingest-user-agent]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [lang-expression]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [lang-mustache]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [lang-painless]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [mapper-extras]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [opensearch-dashboards]
# opensearch-node1  | [2023-11-16T13:05:35,229][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [parent-join]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [percolator]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [rank-eval]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [reindex]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [repository-url]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [search-pipeline-common]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [systemd]
# opensearch-node1  | [2023-11-16T13:05:35,230][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded module [transport-netty4]
# opensearch-node1  | [2023-11-16T13:05:35,231][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [analysis-icu]
# opensearch-node1  | [2023-11-16T13:05:35,231][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [analysis-kuromoji]
# opensearch-node1  | [2023-11-16T13:05:35,231][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-alerting]
# opensearch-node1  | [2023-11-16T13:05:35,231][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-anomaly-detection]
# opensearch-node1  | [2023-11-16T13:05:35,231][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-asynchronous-search]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-cross-cluster-replication]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-custom-codecs]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-geospatial]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-index-management]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-job-scheduler]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-knn]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-ml]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-neural-search]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-notifications]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-notifications-core]
# opensearch-node1  | [2023-11-16T13:05:35,232][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-observability]
# opensearch-node1  | [2023-11-16T13:05:35,234][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-performance-analyzer]
# opensearch-node1  | [2023-11-16T13:05:35,234][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-reports-scheduler]
# opensearch-node1  | [2023-11-16T13:05:35,234][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-security]
# opensearch-node1  | [2023-11-16T13:05:35,234][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-security-analytics]
# opensearch-node1  | [2023-11-16T13:05:35,234][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] loaded plugin [opensearch-sql]
# opensearch-node1  | [2023-11-16T13:05:35,295][INFO ][o.o.e.ExtensionsManager  ] [67e1a2061aa1] ExtensionsManager initialized
# opensearch-node1  | [2023-11-16T13:05:35,318][INFO ][o.o.e.NodeEnvironment    ] [67e1a2061aa1] using [1] data paths, mounts [[/usr/share/opensearch/data (/dev/sdc)]], net usable_space [920.1gb], net total_space [1006.8gb], types [ext4]
# opensearch-node1  | [2023-11-16T13:05:35,318][INFO ][o.o.e.NodeEnvironment    ] [67e1a2061aa1] heap size b], compressed ordinary object pointers [true]
# opensearch-node1  | [2023-11-16T13:05:35,357][INFO ][o.o.n.Node               ] [67e1a2061aa1] node name [67e1a2061aa1], node ID [71i0h9t7QEmJi1uqUB_5JA], cluster name [docker-cluster], roles [ingest, remote_cluster_client, data, cluster_manager]
# opensearch-node1  | [2023-11-16T13:05:37,055][DEPRECATION][o.o.d.c.s.Settings       ] [67e1a2061aa1] [index.store.hybrid.mmap.extensions] setting was deprecated in OpenSearch and will be removed in a future release! See the breaking changes documentation for the next major version.
# opensearch-node1  | [2023-11-16T13:05:37,652][INFO ][o.o.n.p.NeuralSearch     ] [67e1a2061aa1] Registering hybrid query phase searcher with feature flag [plugins.neural_search.hybrid_search_disabled]
# opensearch-node1  | [2023-11-16T13:05:38,075][INFO ][o.o.a.b.ADCircuitBreakerService] [67e1a2061aa1] Registered memory breaker.
# opensearch-node1  | [2023-11-16T13:05:38,350][INFO ][o.o.m.b.MLCircuitBreakerService] [67e1a2061aa1] Registered ML memory breaker.
# opensearch-node1  | [2023-11-16T13:05:38,351][INFO ][o.o.m.b.MLCircuitBreakerService] [67e1a2061aa1] Registered ML disk breaker.
# opensearch-node1  | [2023-11-16T13:05:38,351][INFO ][o.o.m.b.MLCircuitBreakerService] [67e1a2061aa1] Registered ML native memory breaker.
# opensearch-node1  | [2023-11-16T13:05:38,426][INFO ][o.r.Reflections          ] [67e1a2061aa1] Reflections took 42 ms to scan 1 urls, producing 20 keys and 51 values
# opensearch-node1  | [2023-11-16T13:05:38,482][WARN ][o.o.s.p.SQLPlugin        ] [67e1a2061aa1] Master key is a required config for using create and update datasource APIs. Please set plugins.query.datasources.encryption.masterkey config in opensearch.yml in all the cluster nodes. More details can be found here: https://github.com/opensearch-project/sql/blob/main/docs/user/ppl/admin/datasources.rst#master-key-config-for-encrypting-credential-information
# opensearch-node1  | [2023-11-16T13:05:38,506][WARN ][o.o.s.p.SQLPlugin        ] [67e1a2061aa1] Async Query APIs are disabled as plugins.query.executionengine.spark.config is not configured properly in cluster settings. Please configure and restart the domain to enable Async Query APIs
# opensearch-node1  | [2023-11-16T13:05:39,014][INFO ][o.o.t.NettyAllocator     ] [67e1a2061aa1] creating NettyAllocator with the following configs: [name=unpooled, suggested_max_allocation_size=256kb, factors={opensearch.unsafe.use_unpooled_allocator=null, g1gc_enabled=true, g1gc_region_size=1mb, heap_size=512mb}]
# opensearch-node1  | [2023-11-16T13:05:39,119][INFO ][o.o.d.DiscoveryModule    ] [67e1a2061aa1] using discovery type [single-node] and seed hosts providers [settings]
# opensearch-node1  | [2023-11-16T13:05:39,539][WARN ][o.o.g.DanglingIndicesState] [67e1a2061aa1] gateway.auto_import_dangling_indices is disabled, dangling indices will not be automatically detected or imported and must be managed manually
# opensearch-node1  | [2023-11-16T13:05:39,917][INFO ][o.o.p.h.c.PerformanceAnalyzerConfigAction] [67e1a2061aa1] PerformanceAnalyzer Enabled: false
# opensearch-node1  | [2023-11-16T13:05:39,950][INFO ][o.o.n.Node               ] [67e1a2061aa1] initialized
# opensearch-node1  | [2023-11-16T13:05:39,950][INFO ][o.o.n.Node               ] [67e1a2061aa1] starting ...
# opensearch-node1  | [2023-11-16T13:05:39,977][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [windows_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,978][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [waf_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,979][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [vpcflow_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,980][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [test_windows_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,980][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [s3_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,981][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_web_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,982][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_proxy_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,982][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_macos_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,983][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_compliance_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,983][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_cloud_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,984][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_apt_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,984][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [others_application_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,985][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [okta_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,986][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [network_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,987][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [netflow_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,987][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [m365_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,988][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [linux_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,989][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [gworkspace_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,989][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [github_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,990][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [dns_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,990][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [cloudtrail_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,991][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [azure_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,992][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [apache_access_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:39,992][INFO ][o.o.s.l.BuiltinLogTypeLoader] [67e1a2061aa1] Loaded [ad_ldap_logtype.json] log type
# opensearch-node1  | [2023-11-16T13:05:40,086][INFO ][o.o.t.TransportService   ] [67e1a2061aa1] publish_address {172.21.0.2:9300}, bound_addresses {0.0.0.0:9300}
# opensearch-node1  | [2023-11-16T13:05:40,088][INFO ][o.o.t.TransportService   ] [67e1a2061aa1] Remote clusters initialized successfully.
# opensearch-node1  | [2023-11-16T13:05:40,591][INFO ][o.o.c.c.Coordinator      ] [67e1a2061aa1] setting initial configuration to VotingConfiguration{71i0h9t7QEmJi1uqUB_5JA}
# opensearch-node1  | [2023-11-16T13:05:41,010][INFO ][o.o.c.s.MasterService    ] [67e1a2061aa1] elected-as-cluster-manager ([1] nodes joined)[{67e1a2061aa1}{71i0h9t7QEmJi1uqUB_5JA}{6MJCqsaBQtCXD1-bHpn7iA}{172.21.0.2}{172.21.0.2:9300}{dimr}{shard_indexing_pressure_enabled=true} elect leader, _BECOME_CLUSTER_MANAGER_TASK_, _FINISH_ELECTION_], term: 1, version: 1, delta: cluster-manager node changed {previous [], current [{67e1a2061aa1}{71i0h9t7QEmJi1uqUB_5JA}{6MJCqsaBQtCXD1-bHpn7iA}{172.21.0.2}{172.21.0.2:9300}{dimr}{shard_indexing_pressure_enabled=true}]}
# opensearch-node1  | [2023-11-16T13:05:41,259][INFO ][o.o.c.c.CoordinationState] [67e1a2061aa1] cluster UUID set to [o8uk2b1HRKS7pipIqkTlvw]
# opensearch-node1  | [2023-11-16T13:05:41,535][INFO ][o.o.c.s.ClusterApplierService] [67e1a2061aa1] cluster-manager node changed {previous [], current [{67e1a2061aa1}{71i0h9t7QEmJi1uqUB_5JA}{6MJCqsaBQtCXD1-bHpn7iA}{172.21.0.2}{172.21.0.2:9300}{dimr}{shard_indexing_pressure_enabled=true}]}, term: 1, version: 1, reason: Publication{term=1, version=1}
# opensearch-node1  | [2023-11-16T13:05:41,551][INFO ][o.o.a.c.ADClusterEventListener] [67e1a2061aa1] Cluster is not recovered yet.
# opensearch-node1  | [2023-11-16T13:05:41,560][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:41,596][INFO ][o.o.i.i.ManagedIndexCoordinator] [67e1a2061aa1] Cache cluster manager node onClusterManager time: 1700139941596
# opensearch-node1  | [2023-11-16T13:05:41,620][WARN ][o.o.p.c.s.h.ConfigOverridesClusterSettingHandler] [67e1a2061aa1] Config override setting update called with empty string. Ignoring.
# opensearch-node1  | [2023-11-16T13:05:41,675][INFO ][o.o.d.PeerFinder         ] [67e1a2061aa1] setting findPeersInterval to [1s] as node commission status = [true] for local node [{67e1a2061aa1}{71i0h9t7QEmJi1uqUB_5JA}{6MJCqsaBQtCXD1-bHpn7iA}{172.21.0.2}{172.21.0.2:9300}{dimr}{shard_indexing_pressure_enabled=true}]
# opensearch-node1  | [2023-11-16T13:05:41,679][INFO ][o.o.h.AbstractHttpServerTransport] [67e1a2061aa1] publish_address {172.21.0.2:9200}, bound_addresses {0.0.0.0:9200}
# opensearch-node1  | [2023-11-16T13:05:41,679][INFO ][o.o.n.Node               ] [67e1a2061aa1] started
# opensearch-node1  | [2023-11-16T13:05:41,680][INFO ][o.o.s.OpenSearchSecurityPlugin] [67e1a2061aa1] Node started
# opensearch-node1  | [2023-11-16T13:05:41,681][INFO ][o.o.s.OpenSearchSecurityPlugin] [67e1a2061aa1] 0 OpenSearch Security modules loaded so far: []
# opensearch-node1  | [2023-11-16T13:05:41,773][INFO ][o.o.a.c.HashRing         ] [67e1a2061aa1] Node added: [71i0h9t7QEmJi1uqUB_5JA]
# opensearch-node1  | [2023-11-16T13:05:41,775][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:41,777][INFO ][o.o.a.c.HashRing         ] [67e1a2061aa1] Add data node to AD version hash ring: 71i0h9t7QEmJi1uqUB_5JA
# opensearch-node1  | [2023-11-16T13:05:41,780][INFO ][o.o.a.c.HashRing         ] [67e1a2061aa1] All nodes with known AD version: {71i0h9t7QEmJi1uqUB_5JA=ADNodeInfo{version=2.11.0, isEligibleDataNode=true}}
# opensearch-node1  | [2023-11-16T13:05:41,781][INFO ][o.o.a.c.HashRing         ] [67e1a2061aa1] Rebuild AD hash ring for realtime AD with cooldown, nodeChangeEvents size 0
# opensearch-node1  | [2023-11-16T13:05:41,781][INFO ][o.o.a.c.HashRing         ] [67e1a2061aa1] Build AD version hash ring successfully
# opensearch-node1  | [2023-11-16T13:05:41,782][INFO ][o.o.a.c.ADDataMigrator   ] [67e1a2061aa1] Start migrating AD data
# opensearch-node1  | [2023-11-16T13:05:41,782][INFO ][o.o.a.c.ADDataMigrator   ] [67e1a2061aa1] AD job index doesn't exist, no need to migrate
# opensearch-node1  | [2023-11-16T13:05:41,782][INFO ][o.o.a.c.ADClusterEventListener] [67e1a2061aa1] Init AD version hash ring successfully
# opensearch-node1  | [2023-11-16T13:05:41,830][INFO ][o.o.g.GatewayService     ] [67e1a2061aa1] recovered [0] indices into cluster_state
# opensearch-node1  | [2023-11-16T13:05:41,870][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw]
# opensearch-node1  | [2023-11-16T13:05:42,842][INFO ][o.o.c.m.MetadataCreateIndexService] [67e1a2061aa1] [.opensearch-sap-log-types-config] creating index, cause [auto(sap-logtype api)], templates [], shards [1]/[1]
# opensearch-node1  | [2023-11-16T13:05:42,852][INFO ][o.o.c.r.a.AllocationService] [67e1a2061aa1] updating number_of_replicas to [0] for indices [.opensearch-sap-log-types-config]
# opensearch-node1  | [2023-11-16T13:05:43,149][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw]
# opensearch-node1  | [2023-11-16T13:05:43,359][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:43,363][DEPRECATION][o.o.d.c.m.MetadataCreateIndexService] [67e1a2061aa1] index name [.opensearch-observability] starts with a dot '.', in the next major version, index names starting with a dot are reserved for hidden indices and system indices
# opensearch-node1  | [2023-11-16T13:05:43,366][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-observability/ALUAMoxJQDqdnUnupiGDDQ]
# opensearch-node1  | [2023-11-16T13:05:43,385][INFO ][o.o.c.m.MetadataCreateIndexService] [67e1a2061aa1] [.opensearch-observability] creating index, cause [api], templates [], shards [1]/[0]
# opensearch-node1  | [2023-11-16T13:05:43,726][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-observability/ALUAMoxJQDqdnUnupiGDDQ]
# opensearch-node1  | [2023-11-16T13:05:43,975][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:43,979][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Loading builtin types!
# opensearch-node1  | [2023-11-16T13:05:43,984][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Indexing [429] fieldMappingDocs from logTypes: 24
# opensearch-node1  | [2023-11-16T13:05:44,033][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Loading builtin types!
# opensearch-node1  | [2023-11-16T13:05:44,034][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Indexing [429] fieldMappingDocs from logTypes: 24
# opensearch-node1  | [2023-11-16T13:05:44,046][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.kibana_1/Zj33vvY_QaiuKRhxXPQr3Q]
# opensearch-node1  | [2023-11-16T13:05:44,088][INFO ][o.o.c.m.MetadataCreateIndexService] [67e1a2061aa1] [.kibana_1] creating index, cause [api], templates [], shards [1]/[1]
# opensearch-node1  | [2023-11-16T13:05:44,090][INFO ][o.o.c.r.a.AllocationService] [67e1a2061aa1] updating number_of_replicas to [0] for indices [.kibana_1]
# opensearch-node1  | [2023-11-16T13:05:44,509][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.kibana_1/Zj33vvY_QaiuKRhxXPQr3Q]
# opensearch-node1  | [2023-11-16T13:05:44,737][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:45,097][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:45,107][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Loading builtin types!
# opensearch-node1  | [2023-11-16T13:05:45,109][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Indexing [429] fieldMappingDocs from logTypes: 24
# opensearch-node1  | [2023-11-16T13:05:45,189][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Indexing [429] fieldMappingDocs
# opensearch-node1  | [2023-11-16T13:05:45,496][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:45,498][INFO ][o.o.o.i.ObservabilityIndex] [67e1a2061aa1] observability:Index .opensearch-observability creation Acknowledged
# opensearch-node1  | [2023-11-16T13:05:45,499][INFO ][o.o.o.i.ObservabilityIntegrationsIndex] [67e1a2061aa1] observability:createMappingTemplate ss4o_metrics_template API called
# opensearch-node1  | [2023-11-16T13:05:45,502][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw]
# opensearch-node1  | [2023-11-16T13:05:45,523][INFO ][o.o.c.m.MetadataMappingService] [67e1a2061aa1] [.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw] update_mapping [_doc]
# opensearch-node1  | [2023-11-16T13:05:45,766][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:45,777][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[validate-template-o2lnq9ggr0ksa9ncgkfzdg/Gr1sobdMQXqHPC8rHrOPIA]
# opensearch-node1  | [2023-11-16T13:05:45,807][INFO ][o.o.c.m.MetadataIndexTemplateService] [67e1a2061aa1] adding index template [ss4o_metrics_template] for index patterns [ss4o_metrics-*-*]
# opensearch-node1  | [2023-11-16T13:05:46,048][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:46,050][INFO ][o.o.o.i.ObservabilityIntegrationsIndex] [67e1a2061aa1] observability:Mapping Template ss4o_metrics_template creation Acknowledged
# opensearch-node1  | [2023-11-16T13:05:46,050][INFO ][o.o.o.i.ObservabilityIntegrationsIndex] [67e1a2061aa1] observability:createMappingTemplate ss4o_traces_template API called
# opensearch-node1  | [2023-11-16T13:05:46,051][INFO ][o.o.c.r.a.AllocationService] [67e1a2061aa1] Cluster health status changed from [YELLOW] to [GREEN] (reason: [shards started [[.kibana_1][0]]]).
# opensearch-node1  | [2023-11-16T13:05:46,267][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:46,277][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[validate-template-nzkoyn3vtbuvvuns9pip_q/zxYql3LeSGOnpR6LGRi9Cw]
# opensearch-node1  | [2023-11-16T13:05:46,294][INFO ][o.o.c.m.MetadataIndexTemplateService] [67e1a2061aa1] adding index template [ss4o_traces_template] for index patterns [ss4o_traces-*-*]
# opensearch-node1  | [2023-11-16T13:05:46,593][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:46,595][INFO ][o.o.o.i.ObservabilityIntegrationsIndex] [67e1a2061aa1] observability:Mapping Template ss4o_traces_template creation Acknowledged
# opensearch-node1  | [2023-11-16T13:05:46,836][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:46,840][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw]
# opensearch-node1  | [2023-11-16T13:05:46,893][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw]
# opensearch-node1  | [2023-11-16T13:05:46,907][INFO ][o.o.c.m.MetadataMappingService] [67e1a2061aa1] [.opensearch-sap-log-types-config/IOYzwpoSQGefDm9Ex8gdiw] update_mapping [_doc]
# opensearch-node1  | [2023-11-16T13:05:47,141][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:47,652][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Loaded [429] field mapping docs successfully!
# opensearch-node1  | [2023-11-16T13:05:47,670][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Indexing [23] customLogTypes
# opensearch-node1  | [2023-11-16T13:05:47,763][INFO ][o.o.s.l.LogTypeService   ] [67e1a2061aa1] Loaded [23] customLogType docs successfully!
# opensearch-node1  | [2023-11-16T13:05:47,763][INFO ][o.o.s.SecurityAnalyticsPlugin] [67e1a2061aa1] LogType config index successfully created and builtin log types loaded
# opensearch-node1  | [2023-11-16T13:05:51,619][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.plugins-ml-config/hIP_o_C0RJSZ8RAKPvmqfQ]
# opensearch-node1  | [2023-11-16T13:05:51,626][INFO ][o.o.c.m.MetadataCreateIndexService] [67e1a2061aa1] [.plugins-ml-config] creating index, cause [api], templates [], shards [1]/[1]
# opensearch-node1  | [2023-11-16T13:05:51,627][INFO ][o.o.c.r.a.AllocationService] [67e1a2061aa1] updating number_of_replicas to [0] for indices [.plugins-ml-config]
# opensearch-node1  | [2023-11-16T13:05:51,920][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[.plugins-ml-config/hIP_o_C0RJSZ8RAKPvmqfQ]
# opensearch-node1  | [2023-11-16T13:05:52,083][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:52,576][INFO ][o.o.c.r.a.AllocationService] [67e1a2061aa1] Cluster health status changed from [YELLOW] to [GREEN] (reason: [shards started [[.plugins-ml-config][0]]]).
# opensearch-node1  | [2023-11-16T13:05:52,817][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:05:52,818][INFO ][o.o.m.i.MLIndicesHandler ] [67e1a2061aa1] create index:.plugins-ml-config
# opensearch-node1  | [2023-11-16T13:05:53,021][INFO ][o.o.m.c.MLSyncUpCron     ] [67e1a2061aa1] ML configuration initialized successfully
# opensearch-node1  | [2023-11-16T13:06:41,600][INFO ][o.o.i.i.ManagedIndexCoordinator] [67e1a2061aa1] Performing move cluster state metadata.
# opensearch-node1  | [2023-11-16T13:06:41,601][INFO ][o.o.i.i.MetadataService  ] [67e1a2061aa1] ISM config index not exist, so we cancel the metadata migration job.
# opensearch-node1  | [2023-11-16T13:06:41,601][INFO ][o.o.i.i.ManagedIndexCoordinator] [67e1a2061aa1] Performing ISM template migration.
# opensearch-node1  | [2023-11-16T13:06:41,602][INFO ][o.o.i.i.m.ISMTemplateService] [67e1a2061aa1] Doing ISM template migration 1 time.
# opensearch-node1  | [2023-11-16T13:06:41,602][INFO ][o.o.i.i.m.ISMTemplateService] [67e1a2061aa1] Use 2023-11-16T12:05:41.596Z as migrating ISM template last_updated_time
# opensearch-node1  | [2023-11-16T13:06:41,610][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[simulate_template_index_q0crox3ts_ervtb1spsu8w/iygMJIE2Te2xfb14VpcxQA]
# opensearch-node1  | [2023-11-16T13:06:41,620][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[simulate_template_index_q0crox3ts_ervtb1spsu8w/iygMJIE2Te2xfb14VpcxQA]
# opensearch-node1  | [2023-11-16T13:06:41,638][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[simulate_template_index_ptzfecsfqyqa4tof9m5ilq/RqHLi91lTYyGVo5s2tWQrQ]
# opensearch-node1  | [2023-11-16T13:06:41,644][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[simulate_template_index_ptzfecsfqyqa4tof9m5ilq/RqHLi91lTYyGVo5s2tWQrQ]
# opensearch-node1  | [2023-11-16T13:06:41,652][INFO ][o.o.i.i.m.ISMTemplateService] [67e1a2061aa1] ISM templates: {=[ISMTemplate(indexPatterns=[ss4o_metrics-*-*], priority=1, lastUpdatedTime=2023-11-16T12:05:41.596Z), ISMTemplate(indexPatterns=[ss4o_traces-*-*], priority=1, lastUpdatedTime=2023-11-16T12:05:41.596Z)]}
# opensearch-node1  | [2023-11-16T13:06:41,656][INFO ][o.o.i.i.m.ISMTemplateService] [67e1a2061aa1] Policies to update: []
# opensearch-node1  | [2023-11-16T13:06:41,662][INFO ][o.o.i.i.m.ISMTemplateService] [67e1a2061aa1] Failure experienced when migrating ISM Template and update ISM policies: {}
# opensearch-node1  | [2023-11-16T13:06:41,979][INFO ][o.o.c.s.ClusterSettings  ] [67e1a2061aa1] updating [plugins.index_state_management.template_migration.control] from [0] to [-1]
# opensearch-node1  | [2023-11-16T13:06:41,980][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:06:41,985][INFO ][o.o.i.i.m.ISMTemplateService] [67e1a2061aa1] Successfully update template migration setting
# opensearch-node1  | [2023-11-16T13:07:41,600][INFO ][o.o.i.i.ManagedIndexCoordinator] [67e1a2061aa1] Cancel background move metadata process.
# opensearch-node1  | [2023-11-16T13:07:41,601][INFO ][o.o.i.i.ManagedIndexCoordinator] [67e1a2061aa1] Performing move cluster state metadata.
# opensearch-node1  | [2023-11-16T13:07:41,601][INFO ][o.o.i.i.MetadataService  ] [67e1a2061aa1] Move metadata has finished.
# opensearch-node1  | [2023-11-16T13:10:22,261][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[retriever-index/Fb-gwUitRWmiBIeNj_bPSA]
# opensearch-node1  | [2023-11-16T13:10:22,275][INFO ][o.o.c.m.MetadataCreateIndexService] [67e1a2061aa1] [retriever-index] creating index, cause [api], templates [], shards [1]/[1]
# opensearch-node1  | [2023-11-16T13:10:22,514][INFO ][o.o.p.PluginsService     ] [67e1a2061aa1] PluginService:onIndexModule index:[retriever-index/Fb-gwUitRWmiBIeNj_bPSA]
# opensearch-node1  | [2023-11-16T13:10:22,660][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:10:23,394][INFO ][o.o.a.u.d.DestinationMigrationCoordinator] [67e1a2061aa1] Detected cluster change event for destination migration
# opensearch-node1  | [2023-11-16T13:10:40,582][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:10:41,611][INFO ][o.o.i.i.PluginVersionSweepCoordinator] [67e1a2061aa1] Canceling sweep ism plugin version job
# opensearch-node1  | [2023-11-16T13:15:40,584][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:20:40,585][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:25:40,585][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:30:40,586][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:35:40,587][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:40:40,588][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:45:40,588][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | [2023-11-16T13:50:40,590][INFO ][o.o.j.s.JobSweeper       ] [67e1a2061aa1] Running full sweep
# opensearch-node1  | Disabling execution of install_demo_configuration.sh for OpenSearch Security Plugin
# opensearch-node1  | Disabling OpenSearch Security Plugin
# opensearch-node1  | Enabling execution of OPENSEARCH_HOME/bin/opensearch-performance-analyzer/performance-analyzer-agent-cli for OpenSearch Performance Analyzer Plugin
# opensearch-dashboards  | Disabling OpenSearch Security Dashboards Plugin
# opensearch-dashboards  | Removing securityDashboards...
# opensearch-dashboards  | Plugin removal complete
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["info","plugins-service"],"pid":1,"message":"Plugin \"dataSourceManagement\" has been disabled since the following direct or transitive dependencies are missing or disabled: [dataSource]"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["info","plugins-service"],"pid":1,"message":"Plugin \"dataSource\" is disabled."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["info","plugins-service"],"pid":1,"message":"Plugin \"visTypeXy\" is disabled."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["warning","config","deprecation"],"pid":1,"message":"\"cpu.cgroup.path.override\" is deprecated and has been replaced by \"ops.cGroupOverrides.cpuPath\""}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["warning","config","deprecation"],"pid":1,"message":"\"cpuacct.cgroup.path.override\" is deprecated and has been replaced by \"ops.cGroupOverrides.cpuAcctPath\""}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["warning","config","deprecation"],"pid":1,"message":"\"opensearch.requestHeadersWhitelist\" is deprecated and has been replaced by \"opensearch.requestHeadersAllowlist\""}
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:33Z","tags":["info","plugins-system"],"pid":1,"message":"Setting up [50] plugins: [usageCollection,opensearchDashboardsUsageCollection,opensearchDashboardsLegacy,mapsLegacy,share,opensearchUiShared,legacyExport,embeddable,expressions,data,securityAnalyticsDashboards,home,apmOss,savedObjects,searchRelevanceDashboards,reportsDashboards,dashboard,mlCommonsDashboards,visualizations,visTypeVega,visTypeTimeline,visTypeTable,visTypeMarkdown,visBuilder,visAugmenter,anomalyDetectionDashboards,alertingDashboards,tileMap,regionMap,customImportMapDashboards,inputControlVis,ganttChartDashboards,visualize,queryWorkbenchDashboards,indexManagementDashboards,notificationsDashboards,management,indexPatternManagement,advancedSettings,console,dataExplorer,charts,visTypeVislib,visTypeTimeseries,visTypeTagcloud,visTypeMetric,observabilityDashboards,discover,savedObjectsManagement,bfetch]"}
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | [agentkeepalive:deprecated] options.freeSocketKeepAliveTimeout is deprecated, please use options.freeSocketTimeout instead
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:34Z","tags":["info","savedobjects-service"],"pid":1,"message":"Waiting until all OpenSearch nodes are compatible with OpenSearch Dashboards before starting saved objects migrations..."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:34Z","tags":["error","opensearch","data"],"pid":1,"message":"[ConnectionError]: connect ECONNREFUSED 172.21.0.2:9200"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:34Z","tags":["error","savedobjects-service"],"pid":1,"message":"Unable to retrieve version information from OpenSearch nodes."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:37Z","tags":["error","opensearch","data"],"pid":1,"message":"[ConnectionError]: connect ECONNREFUSED 172.21.0.2:9200"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:39Z","tags":["error","opensearch","data"],"pid":1,"message":"[ConnectionError]: connect ECONNREFUSED 172.21.0.2:9200"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:42Z","tags":["info","savedobjects-service"],"pid":1,"message":"Starting saved objects migrations"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:42Z","tags":["info","savedobjects-service"],"pid":1,"message":"Creating index .kibana_1."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:46Z","tags":["info","savedobjects-service"],"pid":1,"message":"Pointing alias .kibana to .kibana_1."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:46Z","tags":["info","savedobjects-service"],"pid":1,"message":"Finished in 4172ms."}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:46Z","tags":["info","plugins-system"],"pid":1,"message":"Starting [50] plugins: [usageCollection,opensearchDashboardsUsageCollection,opensearchDashboardsLegacy,mapsLegacy,share,opensearchUiShared,legacyExport,embeddable,expressions,data,securityAnalyticsDashboards,home,apmOss,savedObjects,searchRelevanceDashboards,reportsDashboards,dashboard,mlCommonsDashboards,visualizations,visTypeVega,visTypeTimeline,visTypeTable,visTypeMarkdown,visBuilder,visAugmenter,anomalyDetectionDashboards,alertingDashboards,tileMap,regionMap,customImportMapDashboards,inputControlVis,ganttChartDashboards,visualize,queryWorkbenchDashboards,indexManagementDashboards,notificationsDashboards,management,indexPatternManagement,advancedSettings,console,dataExplorer,charts,visTypeVislib,visTypeTimeseries,visTypeTagcloud,visTypeMetric,observabilityDashboards,discover,savedObjectsManagement,bfetch]"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:47Z","tags":["listening","info"],"pid":1,"message":"Server running at http://0.0.0.0:5601"}
# opensearch-dashboards  | {"type":"log","@timestamp":"2023-11-16T13:05:47Z","tags":["info","http","server","OpenSearchDashboards"],"pid":1,"message":"http server running at http://0.0.0.0:5601"}
# opensearch-dashboards  | {"type":"response","@timestamp":"2023-11-16T13:06:21Z","tags":["access:console"],"pid":1,"method":"post","statusCode":200,"req":{"url":"/api/console/proxy?path=_mapping&method=GET","method":"post","headers":{"host":"localhost:5601","connection":"keep-alive","content-length":"0","sec-ch-ua":"\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"","dnt":"1","sec-ch-ua-mobile":"?0","user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36","osd-version":"2.11.0","content-type":"application/json","osd-xsrf":"osd-fetch","sec-ch-ua-platform":"\"Windows\"","accept":"*/*","origin":"http://localhost:5601","sec-fetch-site":"same-origin","sec-fetch-mode":"cors","sec-fetch-dest":"empty","referer":"http://localhost:5601/app/dev_tools","accept-encoding":"gzip, deflate, br","accept-language":"ja-JP,ja;q=0.9"},"remoteAddress":"172.21.0.1","userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36","referer":"http://localhost:5601/app/dev_tools"},"res":{"statusCode":200,"responseTime":106,"contentLength":9},"message":"POST /api/console/proxy?path=_mapping&method=GET 200 106ms - 9.0B"}
# opensearch-dashboards  | {"type":"response","@timestamp":"2023-11-16T13:06:21Z","tags":["access:console"],"pid":1,"method":"post","statusCode":200,"req":{"url":"/api/console/proxy?path=_mapping&method=GET","method":"post","headers":{"host":"localhost:5601","connection":"keep-alive","content-length":"0","sec-ch-ua":"\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"","dnt":"1","sec-ch-ua-mobile":"?0","user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36","osd-version":"2.11.0","content-type":"application/json","osd-xsrf":"osd-fetch","sec-ch-ua-platform":"\"Windows\"","accept":"*/*","origin":"http://localhost:5601","sec-fetch-site":"same-origin","sec-fetch-mode":"cors","sec-fetch-dest":"empty","referer":"http://localhost:5601/app/dev_tools","accept-encoding":"gzip, deflate, br","accept-language":"ja-JP,ja;q=0.9"},"remoteAddress":"172.21.0.1","userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36","referer":"http://localhost:5601/app/dev_tools"},"res":{"statusCode":200,"responseTime":73,"contentLength":9},"message":"POST /api/console/proxy?path=_mapping&method=GET 200 73ms - 9.0B"}
# opensearch-dashboards  | {"type":"response","@timestamp":"2023-11-16T13:06:21Z","tags":["access:console"],"pid":1,"method":"post","statusCode":200,"req":{"url":"/api/console/proxy?path=_mapping&method=GET","method":"post","headers":{"host":"localhost:5601","connection":"keep-alive","content-length":"0","sec-ch-ua":"\"Google Chrome\";v=\"119\", \"Chromium\";v=\"119\", \"Not?A_Brand\";v=\"24\"","dnt":"1","sec-ch-ua-mobile":"?0","user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36","osd-version":"2.11.0","content-type":"application/json","osd-xsrf":"osd-fetch","sec-ch-ua-platform":"\"Windows\"","accept":"*/*","origin":"http://localhost:5601","sec-fetch-site":"same-origin","sec-fetch-mode":"cors","sec-fetch-dest":"empty","referer":"http://localhost:5601/app/dev_tools","accept-encoding":"gzip, deflate, br","accept-language":"ja-JP,ja;q=0.9"},"remoteAddress":"172.21.0.1","userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36","referer":"http://localhost:5601/app/dev_tools"},"res":{"statusCode":200,"responseTime":80,"contentLength":9},"message":"POST /api/console/proxy?path=_mapping&method=GET 200 80ms - 9.0B"}

# %% [markdown]
# ---
# ## 事前準備

# %%
# %pip install -Uq opensearch-py langchain beautifulsoup4 requests boto3 python-dotenv
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests

# %%
from dotenv import load_dotenv

load_dotenv(override=True)
# Out:
# True

# %%
host = 'localhost' #'172.17.0.1'
port = 9200

# %%
from opensearchpy import OpenSearch

client = OpenSearch(
    hosts = [{'host': host, 'port': port}],
    use_ssl = False,
    verify_certs = False
)

info = client.info()
print(f"Welcome to {info['version']['distribution']} {info['version']['number']}!")
# Out:
# Welcome to opensearch 2.11.0!

# %% [markdown]
# ---
# ## 1. Amazon BedrockとのMLコネクターを作成

# %%
body = {
  "name": "Amazon Bedrock Connector: embedding",
  "description": "The connector to the Bedrock Titan embedding model",
  "version": 1,
  "protocol": "aws_sigv4",
  "parameters": {
    "region": os.getenv("AWS_DEFAULT_REGION"),
    "service_name": "bedrock"
  },
  "credential": {
    "access_key": os.getenv("AWS_ACCESS_KEY_ID"),
      "secret_key": os.getenv("AWS_SECRET_ACCESS_KEY")
  },
  "actions": [
    {
      "action_type": "predict",
      "method": "POST",
      "url": "https://bedrock-runtime.us-east-1.amazonaws.com/model/amazon.titan-embed-text-v1/invoke",
      "headers": {
        "content-type": "application/json",
        "x-amz-content-sha256": "required"
      },
      "request_body": "{ \"inputText\": \"${parameters.inputText}\" }",
      "pre_process_function": "\n    StringBuilder builder = new StringBuilder();\n    builder.append(\"\\\"\");\n    String first = params.text_docs[0];\n    builder.append(first);\n    builder.append(\"\\\"\");\n    def parameters = \"{\" +\"\\\"inputText\\\":\" + builder + \"}\";\n    return  \"{\" +\"\\\"parameters\\\":\" + parameters + \"}\";",
      "post_process_function": "\n      def name = \"sentence_embedding\";\n      def dataType = \"FLOAT32\";\n      if (params.embedding == null || params.embedding.length == 0) {\n        return params.message;\n      }\n      def shape = [params.embedding.length];\n      def json = \"{\" +\n                 \"\\\"name\\\":\\\"\" + name + \"\\\",\" +\n                 \"\\\"data_type\\\":\\\"\" + dataType + \"\\\",\" +\n                 \"\\\"shape\\\":\" + shape + \",\" +\n                 \"\\\"data\\\":\" + params.embedding +\n                 \"}\";\n      return json;\n    "
    }
  ]
}

response = requests.post(
  f'http://{host}:{port}/_plugins/_ml/connectors/_create', 
  json=body
  )

response.json()
# Out:
# {'connector_id': 'P1KL2IsBoHnPTWrQwH_H'}

# %%
connector_id = response.json()["connector_id"]
connector_id
# Out:
# 'P1KL2IsBoHnPTWrQwH_H'

# %% [markdown]
# ---
# ## 2. モデルグループを作成

# %%
model_group_name = "bedrock-embedded-model-group"

body = {
    "name": model_group_name
}

response = requests.post(
  f'http://{host}:{port}/_plugins/_ml/model_groups/_register', 
  json=body
  )

response.json()
# Out:
# {'model_group_id': 'QFKM2IsBoHnPTWrQC38q', 'status': 'CREATED'}

# %%
model_group_id = response.json()["model_group_id"]
model_group_id
# Out:
# 'QFKM2IsBoHnPTWrQC38q'

# %% [markdown]
# ---
# ## 3. モデルを作成

# %%
model_name = "bedrock-embedded-model"

body = {
    "name": model_name,
    "function_name": "remote",
    "model_group_id": model_group_id,
    "connector_id": connector_id
}

response = requests.post(
  f'http://{host}:{port}/_plugins/_ml/models/_register', 
  json=body
  )

response.json()
# Out:
# {'task_id': 'QVKM2IsBoHnPTWrQWX9z',
#  'status': 'CREATED',
#  'model_id': 'QlKM2IsBoHnPTWrQXn_-'}

# %%
model_id = response.json()["model_id"]
model_id
# Out:
# 'QlKM2IsBoHnPTWrQXn_-'

# %% [markdown]
# ---
# ## 4. モデルをデプロイ

# %%
response = requests.post(
  f'http://{host}:{port}/_plugins/_ml/models/{model_id}/_deploy', 
  )

response.json()
# Out:
# {'task_id': 'Q1KM2IsBoHnPTWrQlX8y',
#  'task_type': 'DEPLOY_MODEL',
#  'status': 'COMPLETED'}

# %% [markdown]
# ---
# ## 5. Ingestパイプラインを作成

# %%
ingest_pipeline_name = "nlp-ingest-pipeline"
embedding_field = "passage_embedding"
embedding_target_field = "question"

body = {
  "description": "An NLP ingest pipeline",
  "processors": [
    {
      "text_embedding": {
        "model_id": model_id,
        "field_map": {
          embedding_target_field: embedding_field
        }
      }
    }
  ]
}

response = requests.put(
  f'http://{host}:{port}/_ingest/pipeline/{ingest_pipeline_name}', 
  json=body
  )

response.json()
# Out:
# {'acknowledged': True}

# %% [markdown]
# ---
# ## 6. Searchパイプラインを作成

# %%
search_pipeline_name = 'nlp-search-pipeline'

body = {
  "description": "Post processor for hybrid search",
  "phase_results_processors": [
    {
      "normalization-processor": {
        "normalization": {
          "technique": "min_max"
        },
        "combination": {
          "technique": "arithmetic_mean",
          "parameters": {
            "weights": [
              0.3,
              0.7
            ]
          }
        }
      }
    }
  ]
}

response = requests.put(
  f'http://{host}:{port}/_search/pipeline/{search_pipeline_name}', 
  json=body
  )

response.json()
# Out:
# {'acknowledged': True}

# %% [markdown]
# ---
# ## 1. インデックスを作成

# %%
index_name = 'semantic-index'

# %%
body = {
  "settings": {
    "index.knn": True,
    "default_pipeline": ingest_pipeline_name,
    "index": {
      "analysis": {
        "analyzer": {
          "custom_kuromoji_analyzer": {
            "tokenizer": "kuromoji_tokenizer",
            "filter": ["kuromoji_baseform", "ja_stop"],
            "char_filter": ["icu_normalizer"]
          }
        }
      }
    }
  },
  "mappings": {
    "properties": {
      embedding_field: {
        "type": "knn_vector",
        "dimension": 1536
      },
      "question": {"type": "text", "analyzer": "custom_kuromoji_analyzer"},
      "answer": {"type": "text", "analyzer": "custom_kuromoji_analyzer"}
    }
  }
}

response = client.indices.create(
  index_name, 
  body=body
)

print(response)
# Out:
# {'acknowledged': True, 'shards_acknowledged': True, 'index': 'semantic-index'}

# %% [markdown]
# ---
# ## 2. データを登録

# %%
from langchain.document_loaders import WebBaseLoader
from langchain.text_splitter import CharacterTextSplitter

loader = WebBaseLoader("https://aws.amazon.com/jp/ec2/faqs/")
data = loader.load()

text_splitter = CharacterTextSplitter(
    separator = "Q:",
    keep_separator=True,
    chunk_size = 10,
    chunk_overlap  = 0,
)

# 先頭のいらないものを消す
texts = text_splitter.split_documents(data)
texts = texts[1:]
# 末尾のいらないものを消す
texts[-1].page_content = texts[-1].page_content.split('\xa0')[0]
# Out:
# Created a chunk of size 1283, which is longer than the specified 10
# Created a chunk of size 154, which is longer than the specified 10
# Created a chunk of size 425, which is longer than the specified 10
# Created a chunk of size 275, which is longer than the specified 10
# Created a chunk of size 190, which is longer than the specified 10
# Created a chunk of size 582, which is longer than the specified 10
# Created a chunk of size 832, which is longer than the specified 10
# Created a chunk of size 483, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 826, which is longer than the specified 10
# Created a chunk of size 211, which is longer than the specified 10
# Created a chunk of size 574, which is longer than the specified 10
# Created a chunk of size 322, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 365, which is longer than the specified 10
# Created a chunk of size 298, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 964, which is longer than the specified 10
# Created a chunk of size 225, which is longer than the specified 10
# Created a chunk of size 507, which is longer than the specified 10
# Created a chunk of size 614, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 73, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 298, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 448, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 384, which is longer than the specified 10
# Created a chunk of size 302, which is longer than the specified 10
# Created a chunk of size 641, which is longer than the specified 10
# Created a chunk of size 356, which is longer than the specified 10
# Created a chunk of size 317, which is longer than the specified 10
# Created a chunk of size 792, which is longer than the specified 10
# Created a chunk of size 276, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 261, which is longer than the specified 10
# Created a chunk of size 348, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 775, which is longer than the specified 10
# Created a chunk of size 501, which is longer than the specified 10
# Created a chunk of size 209, which is longer than the specified 10
# Created a chunk of size 336, which is longer than the specified 10
# Created a chunk of size 260, which is longer than the specified 10
# Created a chunk of size 547, which is longer than the specified 10
# Created a chunk of size 313, which is longer than the specified 10
# Created a chunk of size 205, which is longer than the specified 10
# Created a chunk of size 171, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 415, which is longer than the specified 10
# Created a chunk of size 382, which is longer than the specified 10
# Created a chunk of size 475, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 865, which is longer than the specified 10
# Created a chunk of size 337, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 114, which is longer than the specified 10
# Created a chunk of size 487, which is longer than the specified 10
# Created a chunk of size 461, which is longer than the specified 10
# Created a chunk of size 420, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 430, which is longer than the specified 10
# Created a chunk of size 336, which is longer than the specified 10
# Created a chunk of size 505, which is longer than the specified 10
# Created a chunk of size 334, which is longer than the specified 10
# Created a chunk of size 395, which is longer than the specified 10
# Created a chunk of size 1228, which is longer than the specified 10
# Created a chunk of size 433, which is longer than the specified 10
# Created a chunk of size 224, which is longer than the specified 10
# Created a chunk of size 431, which is longer than the specified 10
# Created a chunk of size 278, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 232, which is longer than the specified 10
# Created a chunk of size 397, which is longer than the specified 10
# Created a chunk of size 417, which is longer than the specified 10
# Created a chunk of size 303, which is longer than the specified 10
# Created a chunk of size 563, which is longer than the specified 10
# Created a chunk of size 370, which is longer than the specified 10
# Created a chunk of size 676, which is longer than the specified 10
# Created a chunk of size 322, which is longer than the specified 10
# Created a chunk of size 225, which is longer than the specified 10
# Created a chunk of size 504, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 352, which is longer than the specified 10
# Created a chunk of size 236, which is longer than the specified 10
# Created a chunk of size 370, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 624, which is longer than the specified 10
# Created a chunk of size 108, which is longer than the specified 10
# Created a chunk of size 251, which is longer than the specified 10
# Created a chunk of size 583, which is longer than the specified 10
# Created a chunk of size 2304, which is longer than the specified 10
# Created a chunk of size 402, which is longer than the specified 10
# Created a chunk of size 399, which is longer than the specified 10
# Created a chunk of size 192, which is longer than the specified 10
# Created a chunk of size 269, which is longer than the specified 10
# Created a chunk of size 537, which is longer than the specified 10
# Created a chunk of size 453, which is longer than the specified 10
# Created a chunk of size 168, which is longer than the specified 10
# Created a chunk of size 363, which is longer than the specified 10
# Created a chunk of size 172, which is longer than the specified 10
# Created a chunk of size 402, which is longer than the specified 10
# Created a chunk of size 423, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 224, which is longer than the specified 10
# Created a chunk of size 442, which is longer than the specified 10
# Created a chunk of size 284, which is longer than the specified 10
# Created a chunk of size 333, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 626, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 235, which is longer than the specified 10
# Created a chunk of size 225, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 356, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 449, which is longer than the specified 10
# Created a chunk of size 260, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 543, which is longer than the specified 10
# Created a chunk of size 879, which is longer than the specified 10
# Created a chunk of size 427, which is longer than the specified 10
# Created a chunk of size 280, which is longer than the specified 10
# Created a chunk of size 341, which is longer than the specified 10
# Created a chunk of size 736, which is longer than the specified 10
# Created a chunk of size 292, which is longer than the specified 10
# Created a chunk of size 275, which is longer than the specified 10
# Created a chunk of size 263, which is longer than the specified 10
# Created a chunk of size 338, which is longer than the specified 10
# Created a chunk of size 409, which is longer than the specified 10
# Created a chunk of size 174, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 139, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 204, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 664, which is longer than the specified 10
# Created a chunk of size 314, which is longer than the specified 10
# Created a chunk of size 181, which is longer than the specified 10
# Created a chunk of size 230, which is longer than the specified 10
# Created a chunk of size 353, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 624, which is longer than the specified 10
# Created a chunk of size 949, which is longer than the specified 10
# Created a chunk of size 282, which is longer than the specified 10
# Created a chunk of size 264, which is longer than the specified 10
# Created a chunk of size 291, which is longer than the specified 10
# Created a chunk of size 228, which is longer than the specified 10
# Created a chunk of size 191, which is longer than the specified 10
# Created a chunk of size 308, which is longer than the specified 10
# Created a chunk of size 537, which is longer than the specified 10
# Created a chunk of size 712, which is longer than the specified 10
# Created a chunk of size 420, which is longer than the specified 10
# Created a chunk of size 379, which is longer than the specified 10
# Created a chunk of size 305, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 718, which is longer than the specified 10
# Created a chunk of size 269, which is longer than the specified 10
# Created a chunk of size 83, which is longer than the specified 10
# Created a chunk of size 64, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 108, which is longer than the specified 10
# Created a chunk of size 151, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 365, which is longer than the specified 10
# Created a chunk of size 428, which is longer than the specified 10
# Created a chunk of size 322, which is longer than the specified 10
# Created a chunk of size 404, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 250, which is longer than the specified 10
# Created a chunk of size 479, which is longer than the specified 10
# Created a chunk of size 233, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 315, which is longer than the specified 10
# Created a chunk of size 300, which is longer than the specified 10
# Created a chunk of size 217, which is longer than the specified 10
# Created a chunk of size 755, which is longer than the specified 10
# Created a chunk of size 348, which is longer than the specified 10
# Created a chunk of size 356, which is longer than the specified 10
# Created a chunk of size 346, which is longer than the specified 10
# Created a chunk of size 863, which is longer than the specified 10
# Created a chunk of size 539, which is longer than the specified 10
# Created a chunk of size 200, which is longer than the specified 10
# Created a chunk of size 100, which is longer than the specified 10
# Created a chunk of size 433, which is longer than the specified 10
# Created a chunk of size 124, which is longer than the specified 10
# Created a chunk of size 154, which is longer than the specified 10
# Created a chunk of size 236, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 160, which is longer than the specified 10
# Created a chunk of size 144, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 110, which is longer than the specified 10
# Created a chunk of size 339, which is longer than the specified 10
# Created a chunk of size 251, which is longer than the specified 10
# Created a chunk of size 577, which is longer than the specified 10
# Created a chunk of size 219, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 87, which is longer than the specified 10
# Created a chunk of size 144, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 138, which is longer than the specified 10
# Created a chunk of size 105, which is longer than the specified 10
# Created a chunk of size 85, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 388, which is longer than the specified 10
# Created a chunk of size 227, which is longer than the specified 10
# Created a chunk of size 233, which is longer than the specified 10
# Created a chunk of size 157, which is longer than the specified 10
# Created a chunk of size 270, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 332, which is longer than the specified 10
# Created a chunk of size 295, which is longer than the specified 10
# Created a chunk of size 247, which is longer than the specified 10
# Created a chunk of size 268, which is longer than the specified 10
# Created a chunk of size 118, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 323, which is longer than the specified 10
# Created a chunk of size 331, which is longer than the specified 10
# Created a chunk of size 778, which is longer than the specified 10
# Created a chunk of size 273, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 260, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 385, which is longer than the specified 10
# Created a chunk of size 131, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 526, which is longer than the specified 10
# Created a chunk of size 250, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 334, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 293, which is longer than the specified 10
# Created a chunk of size 404, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 492, which is longer than the specified 10
# Created a chunk of size 129, which is longer than the specified 10
# Created a chunk of size 546, which is longer than the specified 10
# Created a chunk of size 327, which is longer than the specified 10
# Created a chunk of size 211, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 170, which is longer than the specified 10
# Created a chunk of size 314, which is longer than the specified 10
# Created a chunk of size 170, which is longer than the specified 10
# Created a chunk of size 142, which is longer than the specified 10
# Created a chunk of size 349, which is longer than the specified 10
# Created a chunk of size 818, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 180, which is longer than the specified 10
# Created a chunk of size 309, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 234, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 109, which is longer than the specified 10
# Created a chunk of size 196, which is longer than the specified 10
# Created a chunk of size 49, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 161, which is longer than the specified 10
# Created a chunk of size 273, which is longer than the specified 10
# Created a chunk of size 219, which is longer than the specified 10
# Created a chunk of size 512, which is longer than the specified 10
# Created a chunk of size 204, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 238, which is longer than the specified 10
# Created a chunk of size 289, which is longer than the specified 10
# Created a chunk of size 331, which is longer than the specified 10
# Created a chunk of size 126, which is longer than the specified 10
# Created a chunk of size 297, which is longer than the specified 10
# Created a chunk of size 158, which is longer than the specified 10
# Created a chunk of size 241, which is longer than the specified 10
# Created a chunk of size 214, which is longer than the specified 10
# Created a chunk of size 361, which is longer than the specified 10
# Created a chunk of size 365, which is longer than the specified 10
# Created a chunk of size 1130, which is longer than the specified 10
# Created a chunk of size 468, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 130, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 264, which is longer than the specified 10
# Created a chunk of size 543, which is longer than the specified 10
# Created a chunk of size 221, which is longer than the specified 10
# Created a chunk of size 348, which is longer than the specified 10
# Created a chunk of size 232, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 106, which is longer than the specified 10
# Created a chunk of size 369, which is longer than the specified 10
# Created a chunk of size 337, which is longer than the specified 10
# Created a chunk of size 316, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 197, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 68, which is longer than the specified 10
# Created a chunk of size 172, which is longer than the specified 10
# Created a chunk of size 91, which is longer than the specified 10
# Created a chunk of size 221, which is longer than the specified 10
# Created a chunk of size 101, which is longer than the specified 10
# Created a chunk of size 226, which is longer than the specified 10
# Created a chunk of size 139, which is longer than the specified 10
# Created a chunk of size 231, which is longer than the specified 10
# Created a chunk of size 49, which is longer than the specified 10
# Created a chunk of size 377, which is longer than the specified 10
# Created a chunk of size 371, which is longer than the specified 10
# Created a chunk of size 140, which is longer than the specified 10
# Created a chunk of size 59, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 172, which is longer than the specified 10
# Created a chunk of size 182, which is longer than the specified 10
# Created a chunk of size 169, which is longer than the specified 10
# Created a chunk of size 265, which is longer than the specified 10
# Created a chunk of size 153, which is longer than the specified 10
# Created a chunk of size 105, which is longer than the specified 10
# Created a chunk of size 284, which is longer than the specified 10
# Created a chunk of size 472, which is longer than the specified 10
# Created a chunk of size 94, which is longer than the specified 10
# Created a chunk of size 116, which is longer than the specified 10
# Created a chunk of size 449, which is longer than the specified 10
# Created a chunk of size 356, which is longer than the specified 10
# Created a chunk of size 714, which is longer than the specified 10
# Created a chunk of size 468, which is longer than the specified 10
# Created a chunk of size 644, which is longer than the specified 10
# Created a chunk of size 246, which is longer than the specified 10
# Created a chunk of size 268, which is longer than the specified 10
# Created a chunk of size 162, which is longer than the specified 10
# Created a chunk of size 173, which is longer than the specified 10
# Created a chunk of size 96, which is longer than the specified 10
# Created a chunk of size 420, which is longer than the specified 10
# Created a chunk of size 370, which is longer than the specified 10
# Created a chunk of size 42, which is longer than the specified 10
# Created a chunk of size 251, which is longer than the specified 10
# Created a chunk of size 117, which is longer than the specified 10
# Created a chunk of size 261, which is longer than the specified 10
# Created a chunk of size 206, which is longer than the specified 10
# Created a chunk of size 90, which is longer than the specified 10
# Created a chunk of size 439, which is longer than the specified 10
# Created a chunk of size 99, which is longer than the specified 10
# Created a chunk of size 216, which is longer than the specified 10
# Created a chunk of size 366, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 398, which is longer than the specified 10
# Created a chunk of size 269, which is longer than the specified 10
# Created a chunk of size 113, which is longer than the specified 10
# Created a chunk of size 161, which is longer than the specified 10
# Created a chunk of size 127, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 156, which is longer than the specified 10
# Created a chunk of size 627, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 174, which is longer than the specified 10
# Created a chunk of size 215, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 343, which is longer than the specified 10
# Created a chunk of size 335, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 255, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 108, which is longer than the specified 10
# Created a chunk of size 145, which is longer than the specified 10
# Created a chunk of size 227, which is longer than the specified 10
# Created a chunk of size 221, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 669, which is longer than the specified 10
# Created a chunk of size 232, which is longer than the specified 10
# Created a chunk of size 499, which is longer than the specified 10
# Created a chunk of size 237, which is longer than the specified 10
# Created a chunk of size 341, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 183, which is longer than the specified 10
# Created a chunk of size 60, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 235, which is longer than the specified 10
# Created a chunk of size 92, which is longer than the specified 10
# Created a chunk of size 215, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 210, which is longer than the specified 10
# Created a chunk of size 176, which is longer than the specified 10
# Created a chunk of size 136, which is longer than the specified 10
# Created a chunk of size 178, which is longer than the specified 10
# Created a chunk of size 313, which is longer than the specified 10
# Created a chunk of size 802, which is longer than the specified 10
# Created a chunk of size 564, which is longer than the specified 10
# Created a chunk of size 159, which is longer than the specified 10
# Created a chunk of size 382, which is longer than the specified 10
# Created a chunk of size 245, which is longer than the specified 10
# Created a chunk of size 297, which is longer than the specified 10
# Created a chunk of size 293, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 133, which is longer than the specified 10
# Created a chunk of size 188, which is longer than the specified 10
# Created a chunk of size 252, which is longer than the specified 10
# Created a chunk of size 207, which is longer than the specified 10
# Created a chunk of size 235, which is longer than the specified 10
# Created a chunk of size 152, which is longer than the specified 10
# Created a chunk of size 84, which is longer than the specified 10
# Created a chunk of size 149, which is longer than the specified 10
# Created a chunk of size 238, which is longer than the specified 10
# Created a chunk of size 302, which is longer than the specified 10
# Created a chunk of size 310, which is longer than the specified 10
# Created a chunk of size 358, which is longer than the specified 10
# Created a chunk of size 425, which is longer than the specified 10
# Created a chunk of size 178, which is longer than the specified 10
# Created a chunk of size 313, which is longer than the specified 10
# Created a chunk of size 226, which is longer than the specified 10
# Created a chunk of size 225, which is longer than the specified 10
# Created a chunk of size 97, which is longer than the specified 10
# Created a chunk of size 125, which is longer than the specified 10
# Created a chunk of size 155, which is longer than the specified 10
# Created a chunk of size 268, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 172, which is longer than the specified 10
# Created a chunk of size 205, which is longer than the specified 10
# Created a chunk of size 404, which is longer than the specified 10
# Created a chunk of size 62, which is longer than the specified 10
# Created a chunk of size 107, which is longer than the specified 10
# Created a chunk of size 354, which is longer than the specified 10
# Created a chunk of size 274, which is longer than the specified 10
# Created a chunk of size 134, which is longer than the specified 10
# Created a chunk of size 81, which is longer than the specified 10
# Created a chunk of size 630, which is longer than the specified 10
# Created a chunk of size 93, which is longer than the specified 10
# Created a chunk of size 195, which is longer than the specified 10
# Created a chunk of size 212, which is longer than the specified 10
# Created a chunk of size 302, which is longer than the specified 10
# Created a chunk of size 263, which is longer than the specified 10
# Created a chunk of size 249, which is longer than the specified 10
# Created a chunk of size 179, which is longer than the specified 10
# Created a chunk of size 220, which is longer than the specified 10
# Created a chunk of size 98, which is longer than the specified 10
# Created a chunk of size 245, which is longer than the specified 10
# Created a chunk of size 119, which is longer than the specified 10
# Created a chunk of size 203, which is longer than the specified 10
# Created a chunk of size 358, which is longer than the specified 10
# Created a chunk of size 573, which is longer than the specified 10
# Created a chunk of size 280, which is longer than the specified 10
# Created a chunk of size 642, which is longer than the specified 10
# Created a chunk of size 360, which is longer than the specified 10
# Created a chunk of size 553, which is longer than the specified 10
# Created a chunk of size 213, which is longer than the specified 10
# Created a chunk of size 129, which is longer than the specified 10
# Created a chunk of size 525, which is longer than the specified 10
# Created a chunk of size 165, which is longer than the specified 10
# Created a chunk of size 185, which is longer than the specified 10
# Created a chunk of size 217, which is longer than the specified 10
# Created a chunk of size 102, which is longer than the specified 10
# Created a chunk of size 745, which is longer than the specified 10
# Created a chunk of size 822, which is longer than the specified 10
# Created a chunk of size 738, which is longer than the specified 10
# Created a chunk of size 284, which is longer than the specified 10
# Created a chunk of size 124, which is longer than the specified 10
# Created a chunk of size 240, which is longer than the specified 10
# Created a chunk of size 343, which is longer than the specified 10
# Created a chunk of size 276, which is longer than the specified 10
# Created a chunk of size 112, which is longer than the specified 10
# Created a chunk of size 374, which is longer than the specified 10
# Created a chunk of size 430, which is longer than the specified 10
# Created a chunk of size 159, which is longer than the specified 10
# Created a chunk of size 393, which is longer than the specified 10
# Created a chunk of size 315, which is longer than the specified 10
# Created a chunk of size 293, which is longer than the specified 10
# Created a chunk of size 297, which is longer than the specified 10
# Created a chunk of size 671, which is longer than the specified 10
# Created a chunk of size 277, which is longer than the specified 10
# Created a chunk of size 1418, which is longer than the specified 10
# Created a chunk of size 239, which is longer than the specified 10
# Created a chunk of size 222, which is longer than the specified 10
# Created a chunk of size 79, which is longer than the specified 10
# Created a chunk of size 205, which is longer than the specified 10
# Created a chunk of size 347, which is longer than the specified 10
# Created a chunk of size 463, which is longer than the specified 10
# Created a chunk of size 186, which is longer than the specified 10
# Created a chunk of size 383, which is longer than the specified 10
# Created a chunk of size 187, which is longer than the specified 10
# Created a chunk of size 319, which is longer than the specified 10
# Created a chunk of size 299, which is longer than the specified 10
# Created a chunk of size 449, which is longer than the specified 10
# Created a chunk of size 461, which is longer than the specified 10
# Created a chunk of size 567, which is longer than the specified 10
# Created a chunk of size 199, which is longer than the specified 10
# Created a chunk of size 229, which is longer than the specified 10
# Created a chunk of size 166, which is longer than the specified 10
# Created a chunk of size 194, which is longer than the specified 10
# Created a chunk of size 319, which is longer than the specified 10
# Created a chunk of size 218, which is longer than the specified 10
# Created a chunk of size 472, which is longer than the specified 10
# Created a chunk of size 325, which is longer than the specified 10
# Created a chunk of size 111, which is longer than the specified 10
# Created a chunk of size 272, which is longer than the specified 10
# Created a chunk of size 315, which is longer than the specified 10
# Created a chunk of size 201, which is longer than the specified 10
# Created a chunk of size 201, which is longer than the specified 10
# Created a chunk of size 189, which is longer than the specified 10
# Created a chunk of size 404, which is longer than the specified 10
# Created a chunk of size 342, which is longer than the specified 10
# Created a chunk of size 193, which is longer than the specified 10
# Created a chunk of size 348, which is longer than the specified 10
# Created a chunk of size 221, which is longer than the specified 10
# Created a chunk of size 122, which is longer than the specified 10
# Created a chunk of size 146, which is longer than the specified 10
# Created a chunk of size 242, which is longer than the specified 10
# Created a chunk of size 184, which is longer than the specified 10
# Created a chunk of size 240, which is longer than the specified 10
# Created a chunk of size 221, which is longer than the specified 10
# Created a chunk of size 299, which is longer than the specified 10
# Created a chunk of size 308, which is longer than the specified 10
# Created a chunk of size 141, which is longer than the specified 10
# Created a chunk of size 115, which is longer than the specified 10
# Created a chunk of size 270, which is longer than the specified 10

# %%
for text in texts:
  try:
    lines = text.page_content.splitlines()
    q = lines[0]
    a = text.page_content

    body = {
      "question": q,
      "answer": a
    }

    response = client.index(
      index=index_name,
      body=body
    )

    print(response)
  except Exception as e:
    print(e)
# Out:
# {'_index': 'semantic-index', '_id': 'RFKN2IsBoHnPTWrQ8H87', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'RVKN2IsBoHnPTWrQ838V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'RlKN2IsBoHnPTWrQ9n8O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'R1KN2IsBoHnPTWrQ-H-U', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'SFKN2IsBoHnPTWrQ-391', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'SVKN2IsBoHnPTWrQ_n9Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'SlKO2IsBoHnPTWrQAX9j', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'S1KO2IsBoHnPTWrQBH8D', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'TFKO2IsBoHnPTWrQBn-8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'TVKO2IsBoHnPTWrQCX97', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'TlKO2IsBoHnPTWrQDH94', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'T1KO2IsBoHnPTWrQD39l', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'UFKO2IsBoHnPTWrQEX_s', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'UVKO2IsBoHnPTWrQFH-l', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'UlKO2IsBoHnPTWrQF38u', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'U1KO2IsBoHnPTWrQGX-P', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'VFKO2IsBoHnPTWrQHH9V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'VVKO2IsBoHnPTWrQHn_x', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'VlKO2IsBoHnPTWrQIX-Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'V1KO2IsBoHnPTWrQIn_y', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'WFKO2IsBoHnPTWrQJH9C', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'WVKO2IsBoHnPTWrQJn_L', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'WlKO2IsBoHnPTWrQKH9G', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'W1KO2IsBoHnPTWrQKX-q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'XFKO2IsBoHnPTWrQK38T', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'XVKO2IsBoHnPTWrQLH9x', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'XlKO2IsBoHnPTWrQLX_6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'X1KO2IsBoHnPTWrQMH9h', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'YFKO2IsBoHnPTWrQMX_V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'YVKO2IsBoHnPTWrQNH_6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'YlKO2IsBoHnPTWrQNn9f', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'Y1KO2IsBoHnPTWrQN3_X', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ZFKO2IsBoHnPTWrQOX8n', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ZVKO2IsBoHnPTWrQOn-B', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ZlKO2IsBoHnPTWrQO3_e', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 34, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'Z1KO2IsBoHnPTWrQPX9K', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 35, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'aFKO2IsBoHnPTWrQPn-n', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 36, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'aVKO2IsBoHnPTWrQQH8R', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'alKO2IsBoHnPTWrQQn-z', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 38, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'a1KO2IsBoHnPTWrQRH8e', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 39, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'bFKO2IsBoHnPTWrQRn_Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 40, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'bVKO2IsBoHnPTWrQSH9C', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 41, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'blKO2IsBoHnPTWrQSX-z', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 42, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'b1KO2IsBoHnPTWrQS38u', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 43, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'cFKO2IsBoHnPTWrQTH-V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 44, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'cVKO2IsBoHnPTWrQTX_t', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 45, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'clKO2IsBoHnPTWrQT39E', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 46, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'c1KO2IsBoHnPTWrQUH-S', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 47, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'dFKO2IsBoHnPTWrQUn8A', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 48, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'dVKO2IsBoHnPTWrQVH97', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 49, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'dlKO2IsBoHnPTWrQVX_r', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 50, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'd1KO2IsBoHnPTWrQV39_', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 51, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'eFKO2IsBoHnPTWrQWH_b', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 52, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'eVKO2IsBoHnPTWrQWn83', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 53, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'elKO2IsBoHnPTWrQW3-Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 54, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'e1KO2IsBoHnPTWrQXX8B', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 55, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'fFKO2IsBoHnPTWrQXn9_', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 56, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'fVKO2IsBoHnPTWrQX3_i', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 57, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'flKO2IsBoHnPTWrQYX9O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 58, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'f1KO2IsBoHnPTWrQY3_c', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 59, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'gFKO2IsBoHnPTWrQZn_V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 60, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'gVKO2IsBoHnPTWrQaH9A', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 61, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'glKO2IsBoHnPTWrQaX-s', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 62, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'g1KO2IsBoHnPTWrQa38W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 63, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'hFKO2IsBoHnPTWrQbH-A', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 64, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'hVKO2IsBoHnPTWrQbX_s', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 65, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'hlKO2IsBoHnPTWrQb391', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 66, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'h1KO2IsBoHnPTWrQcH_j', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 67, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'iFKO2IsBoHnPTWrQcn9T', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 68, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'iVKO2IsBoHnPTWrQc3_e', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 69, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ilKO2IsBoHnPTWrQdX8w', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 70, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'i1KO2IsBoHnPTWrQdn-D', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 71, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'jFKO2IsBoHnPTWrQd3_n', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 72, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'jVKO2IsBoHnPTWrQeX9J', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 73, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'jlKO2IsBoHnPTWrQen-t', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 74, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'j1KO2IsBoHnPTWrQfH8Y', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 75, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'kFKO2IsBoHnPTWrQfX-l', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 76, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'kVKO2IsBoHnPTWrQf381', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 77, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'klKO2IsBoHnPTWrQgH-H', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 78, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'k1KO2IsBoHnPTWrQgX_f', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 79, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'lFKO2IsBoHnPTWrQg39V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 80, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'lVKO2IsBoHnPTWrQhH-_', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 81, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'llKO2IsBoHnPTWrQhn8k', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 82, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'l1KO2IsBoHnPTWrQh39z', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 83, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'mFKO2IsBoHnPTWrQiH_M', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 84, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'mVKO2IsBoHnPTWrQin82', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 85, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'mlKO2IsBoHnPTWrQi3-z', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 86, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'm1KO2IsBoHnPTWrQjX8W', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 87, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'nFKO2IsBoHnPTWrQjn9x', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 88, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'nVKO2IsBoHnPTWrQj3_O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 89, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'nlKO2IsBoHnPTWrQkX8t', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 90, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'n1KO2IsBoHnPTWrQkn-V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 91, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'oFKO2IsBoHnPTWrQlH8N', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 92, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'oVKO2IsBoHnPTWrQlX9w', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 93, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'olKO2IsBoHnPTWrQln_O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 94, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'o1KO2IsBoHnPTWrQmH84', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 95, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'pFKO2IsBoHnPTWrQmX-Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 96, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'pVKO2IsBoHnPTWrQmn_6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 97, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'plKO2IsBoHnPTWrQnH9f', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 98, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'p1KO2IsBoHnPTWrQnX_K', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 99, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'qFKO2IsBoHnPTWrQn38j', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 100, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'qVKO2IsBoHnPTWrQoH91', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 101, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'qlKO2IsBoHnPTWrQoX_V', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 102, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'q1KO2IsBoHnPTWrQo39R', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 103, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'rFKO2IsBoHnPTWrQpH-t', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 104, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'rVKO2IsBoHnPTWrQpn8O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 105, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'rlKO2IsBoHnPTWrQp39q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 106, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'r1KO2IsBoHnPTWrQqH_h', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 107, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'sFKO2IsBoHnPTWrQqn9H', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 108, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'sVKO2IsBoHnPTWrQq3-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 109, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'slKO2IsBoHnPTWrQrX8O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 110, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 's1KO2IsBoHnPTWrQrn9w', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 111, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'tFKO2IsBoHnPTWrQr3_M', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 112, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'tVKO2IsBoHnPTWrQsX80', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 113, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'tlKO2IsBoHnPTWrQsn-_', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 114, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 't1KO2IsBoHnPTWrQtH8j', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 115, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'uFKO2IsBoHnPTWrQtX-g', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 116, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'uVKO2IsBoHnPTWrQt38N', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 117, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ulKO2IsBoHnPTWrQuH93', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 118, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'u1KO2IsBoHnPTWrQuX_u', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 119, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'vFKO2IsBoHnPTWrQu39a', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 120, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'vVKO2IsBoHnPTWrQvH--', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 121, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'vlKO2IsBoHnPTWrQvn8p', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 122, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'v1KO2IsBoHnPTWrQv3-L', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 123, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'wFKO2IsBoHnPTWrQwH_r', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 124, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'wVKO2IsBoHnPTWrQwn9O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 125, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'wlKO2IsBoHnPTWrQw3-3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 126, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'w1KO2IsBoHnPTWrQxX8w', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 127, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'xFKO2IsBoHnPTWrQxn-h', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 128, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'xVKO2IsBoHnPTWrQyH8F', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 129, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'xlKO2IsBoHnPTWrQyX9d', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 130, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'x1KO2IsBoHnPTWrQyn_r', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 131, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'yFKO2IsBoHnPTWrQzH9O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 132, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'yVKO2IsBoHnPTWrQzX-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 133, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ylKO2IsBoHnPTWrQz38U', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 134, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'y1KO2IsBoHnPTWrQ0H-B', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 135, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'zFKO2IsBoHnPTWrQ0X_v', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 136, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'zVKO2IsBoHnPTWrQ039L', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 137, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'zlKO2IsBoHnPTWrQ1H-s', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 138, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'z1KO2IsBoHnPTWrQ1n8l', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 139, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '0FKO2IsBoHnPTWrQ13-T', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 140, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '0VKO2IsBoHnPTWrQ2X8K', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 141, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '0lKO2IsBoHnPTWrQ2n-T', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 142, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '01KO2IsBoHnPTWrQ23_6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 143, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '1FKO2IsBoHnPTWrQ3X9k', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 144, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '1VKO2IsBoHnPTWrQ3n-6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 145, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '1lKO2IsBoHnPTWrQ4H8i', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 146, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '11KO2IsBoHnPTWrQ4X_K', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 147, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '2FKO2IsBoHnPTWrQ438o', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 148, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '2VKO2IsBoHnPTWrQ5H-Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 149, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '2lKO2IsBoHnPTWrQ5n8A', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 150, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '21KO2IsBoHnPTWrQ539s', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 151, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '3FKO2IsBoHnPTWrQ6H_d', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 152, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '3VKO2IsBoHnPTWrQ6n89', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 153, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '3lKO2IsBoHnPTWrQ63-u', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 154, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '31KO2IsBoHnPTWrQ7X8O', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 155, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '4FKO2IsBoHnPTWrQ7n9t', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 156, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '4VKO2IsBoHnPTWrQ73_Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 157, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '4lKO2IsBoHnPTWrQ8X9C', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 158, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '41KO2IsBoHnPTWrQ8n-y', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 159, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '5FKO2IsBoHnPTWrQ9H8X', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 160, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '5VKO2IsBoHnPTWrQ9X97', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 161, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '5lKO2IsBoHnPTWrQ9n_Z', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 162, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '51KO2IsBoHnPTWrQ-H9K', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 163, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '6FKO2IsBoHnPTWrQ-X-u', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 164, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '6VKO2IsBoHnPTWrQ-38p', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 165, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '6lKO2IsBoHnPTWrQ_H-C', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 166, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '61KO2IsBoHnPTWrQ_X_p', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 167, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '7FKO2IsBoHnPTWrQ_39Q', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 168, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '7VKP2IsBoHnPTWrQAH-o', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 169, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '7lKP2IsBoHnPTWrQAn8M', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 170, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '71KP2IsBoHnPTWrQA392', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 171, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '8FKP2IsBoHnPTWrQBH_P', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 172, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '8VKP2IsBoHnPTWrQBn8y', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 173, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '8lKP2IsBoHnPTWrQB3-i', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 174, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '81KP2IsBoHnPTWrQCX8P', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 175, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '9FKP2IsBoHnPTWrQCn98', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 176, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '9VKP2IsBoHnPTWrQC3_c', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 177, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '9lKP2IsBoHnPTWrQDX86', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 178, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '91KP2IsBoHnPTWrQDn-U', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 179, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '-FKP2IsBoHnPTWrQD3__', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 180, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '-VKP2IsBoHnPTWrQEX9b', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 181, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '-lKP2IsBoHnPTWrQEn-1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 182, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '-1KP2IsBoHnPTWrQFH8M', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 183, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '_FKP2IsBoHnPTWrQFX90', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 184, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '_VKP2IsBoHnPTWrQFn_B', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 185, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '_lKP2IsBoHnPTWrQGH8u', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 186, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': '_1KP2IsBoHnPTWrQGX-F', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 187, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'AFKP2IsBoHnPTWrQGoDc', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 188, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'AVKP2IsBoHnPTWrQHIBD', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 189, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'AlKP2IsBoHnPTWrQHYCb', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 190, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'A1KP2IsBoHnPTWrQHoDw', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 191, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'BFKP2IsBoHnPTWrQIIBd', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 192, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'BVKP2IsBoHnPTWrQIYDE', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 193, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'BlKP2IsBoHnPTWrQI4Ac', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 194, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'B1KP2IsBoHnPTWrQJIB-', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 195, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'CFKP2IsBoHnPTWrQJoAB', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 196, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'CVKP2IsBoHnPTWrQJ4Bt', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 197, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ClKP2IsBoHnPTWrQKIDL', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 198, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'C1KP2IsBoHnPTWrQKoAe', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 199, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'DFKP2IsBoHnPTWrQK4CI', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 200, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'DVKP2IsBoHnPTWrQLIDa', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 201, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'DlKP2IsBoHnPTWrQLoAv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 202, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'D1KP2IsBoHnPTWrQL4CW', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 203, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'EFKP2IsBoHnPTWrQMIDr', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 204, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'EVKP2IsBoHnPTWrQMoBB', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 205, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ElKP2IsBoHnPTWrQM4Ca', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 206, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'E1KP2IsBoHnPTWrQNID3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 207, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'FFKP2IsBoHnPTWrQNoBT', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 208, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'FVKP2IsBoHnPTWrQN4C5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 209, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'FlKP2IsBoHnPTWrQOYAR', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 210, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'F1KP2IsBoHnPTWrQOoCF', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 211, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'GFKP2IsBoHnPTWrQO4Dm', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 212, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'GVKP2IsBoHnPTWrQPYBk', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 213, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'GlKP2IsBoHnPTWrQPoC8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 214, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'G1KP2IsBoHnPTWrQQIAV', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 215, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'HFKP2IsBoHnPTWrQQYBz', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 216, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'HVKP2IsBoHnPTWrQQoDQ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 217, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'HlKP2IsBoHnPTWrQRIAl', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 218, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'H1KP2IsBoHnPTWrQRYB2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 219, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'IFKP2IsBoHnPTWrQRoDW', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 220, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'IVKP2IsBoHnPTWrQSIAo', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 221, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'IlKP2IsBoHnPTWrQSYCL', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 222, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'I1KP2IsBoHnPTWrQSoD3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 223, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'JFKP2IsBoHnPTWrQTIBN', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 224, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'JVKP2IsBoHnPTWrQTYCh', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 225, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'JlKP2IsBoHnPTWrQT4AJ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 226, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'J1KP2IsBoHnPTWrQUIBv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 227, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'KFKP2IsBoHnPTWrQUYC8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 228, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'KVKP2IsBoHnPTWrQU4AJ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 229, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'KlKP2IsBoHnPTWrQVICC', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 230, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'K1KP2IsBoHnPTWrQVYDw', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 231, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'LFKP2IsBoHnPTWrQV4BX', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 232, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'LVKP2IsBoHnPTWrQWIC2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 233, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'LlKP2IsBoHnPTWrQWoAi', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 234, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'L1KP2IsBoHnPTWrQW4DE', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 235, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'MFKP2IsBoHnPTWrQXYA3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 236, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'MVKP2IsBoHnPTWrQXoCw', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 237, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'MlKP2IsBoHnPTWrQYIAi', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 238, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'M1KP2IsBoHnPTWrQYYCc', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 239, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'NFKP2IsBoHnPTWrQYoD7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 240, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'NVKP2IsBoHnPTWrQZIBi', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 241, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'NlKP2IsBoHnPTWrQZYDM', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 242, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'N1KP2IsBoHnPTWrQZ4Ap', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 243, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'OFKP2IsBoHnPTWrQaICX', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 244, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'OVKP2IsBoHnPTWrQaYDq', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 245, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'OlKP2IsBoHnPTWrQa4BR', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 246, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'O1KP2IsBoHnPTWrQbIC1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 247, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'PFKP2IsBoHnPTWrQboAr', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 248, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'PVKP2IsBoHnPTWrQb4CT', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 249, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'PlKP2IsBoHnPTWrQcYAK', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 250, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'P1KP2IsBoHnPTWrQcoBo', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 251, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'QFKP2IsBoHnPTWrQc4DE', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 252, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'QVKP2IsBoHnPTWrQdYBf', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 253, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'QlKP2IsBoHnPTWrQdoDC', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 254, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'Q1KP2IsBoHnPTWrQeIAh', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 255, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'RFKP2IsBoHnPTWrQeYCa', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 256, '_primary_term': 1}
# ...
# {'_index': 'semantic-index', '_id': 'F1KQ2IsBoHnPTWrQnYFF', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 467, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'GFKQ2IsBoHnPTWrQnoG5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 468, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'GVKQ2IsBoHnPTWrQoIET', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 469, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'GlKQ2IsBoHnPTWrQoYFw', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 470, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'G1KQ2IsBoHnPTWrQooHZ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 471, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'HFKQ2IsBoHnPTWrQpIFi', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 472, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'HVKQ2IsBoHnPTWrQpYH-', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 473, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'HlKQ2IsBoHnPTWrQp4Fq', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 474, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'H1KQ2IsBoHnPTWrQqIGv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 475, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'IFKQ2IsBoHnPTWrQqoEY', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 476, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'IVKQ2IsBoHnPTWrQq4Fo', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 477, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'IlKQ2IsBoHnPTWrQrIHE', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 478, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'I1KQ2IsBoHnPTWrQroFB', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 479, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'JFKQ2IsBoHnPTWrQr4Gh', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 480, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'JVKQ2IsBoHnPTWrQsIHv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 481, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'JlKQ2IsBoHnPTWrQsoFF', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 482, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'J1KQ2IsBoHnPTWrQs4Gu', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 483, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'KFKQ2IsBoHnPTWrQtYEF', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 484, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'KVKQ2IsBoHnPTWrQtoFb', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 485, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'KlKQ2IsBoHnPTWrQt4Gm', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 486, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'K1KQ2IsBoHnPTWrQuIHs', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 487, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'LFKQ2IsBoHnPTWrQuoFM', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 488, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'LVKQ2IsBoHnPTWrQu4Ga', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 489, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'LlKQ2IsBoHnPTWrQvIHv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 490, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'L1KQ2IsBoHnPTWrQvoFh', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 491, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'MFKQ2IsBoHnPTWrQv4HG', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 492, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'MVKQ2IsBoHnPTWrQwYEY', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 493, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'MlKQ2IsBoHnPTWrQwoGD', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 494, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'M1KQ2IsBoHnPTWrQw4He', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 495, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'NFKQ2IsBoHnPTWrQxYE8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 496, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'NVKQ2IsBoHnPTWrQxoGd', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 497, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'NlKQ2IsBoHnPTWrQx4Ht', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 498, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'N1KQ2IsBoHnPTWrQyYE6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 499, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'OFKQ2IsBoHnPTWrQyoGR', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 500, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'OVKQ2IsBoHnPTWrQy4Hq', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 501, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'OlKQ2IsBoHnPTWrQzYFR', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 502, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'O1KQ2IsBoHnPTWrQzoGg', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 503, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'PFKQ2IsBoHnPTWrQ0IEd', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 504, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'PVKQ2IsBoHnPTWrQ0YF9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 505, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'PlKQ2IsBoHnPTWrQ0oHr', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 506, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'P1KQ2IsBoHnPTWrQ1IFH', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 507, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'QFKQ2IsBoHnPTWrQ1YGr', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 508, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'QVKQ2IsBoHnPTWrQ1oH4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 509, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'QlKQ2IsBoHnPTWrQ2IFN', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 510, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'Q1KQ2IsBoHnPTWrQ2YGt', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 511, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'RFKQ2IsBoHnPTWrQ24EK', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 512, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'RVKQ2IsBoHnPTWrQ3IFX', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 513, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'RlKQ2IsBoHnPTWrQ3YHZ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 514, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'R1KQ2IsBoHnPTWrQ34Ez', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 515, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'SFKQ2IsBoHnPTWrQ4IGV', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 516, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'SVKQ2IsBoHnPTWrQ4oEY', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 517, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'SlKQ2IsBoHnPTWrQ44Fv', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 518, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'S1KQ2IsBoHnPTWrQ5IH8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 519, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'TFKQ2IsBoHnPTWrQ5oFX', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 520, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'TVKQ2IsBoHnPTWrQ54G6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 521, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'TlKQ2IsBoHnPTWrQ6YEZ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 522, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'T1KQ2IsBoHnPTWrQ6oF6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 523, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'UFKQ2IsBoHnPTWrQ64Hb', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 524, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'UVKQ2IsBoHnPTWrQ7YFF', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 525, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'UlKQ2IsBoHnPTWrQ7oGm', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 526, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'U1KQ2IsBoHnPTWrQ8IEG', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 527, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'VFKQ2IsBoHnPTWrQ8YFT', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 528, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'VVKQ2IsBoHnPTWrQ8oGr', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 529, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'VlKQ2IsBoHnPTWrQ9IEK', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 530, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'V1KQ2IsBoHnPTWrQ9YFt', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 531, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'WFKQ2IsBoHnPTWrQ9oHW', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 532, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'WVKQ2IsBoHnPTWrQ-IEa', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 533, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'WlKQ2IsBoHnPTWrQ-YF3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 534, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'W1KQ2IsBoHnPTWrQ-oHI', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 535, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'XFKQ2IsBoHnPTWrQ_IE6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 536, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'XVKQ2IsBoHnPTWrQ_YGN', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 537, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'XlKQ2IsBoHnPTWrQ_oHq', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 538, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'X1KR2IsBoHnPTWrQAIFJ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 539, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'YFKR2IsBoHnPTWrQAYGl', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 540, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'YVKR2IsBoHnPTWrQA4EZ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 541, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'YlKR2IsBoHnPTWrQBIF2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 542, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'Y1KR2IsBoHnPTWrQBYHX', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 543, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ZFKR2IsBoHnPTWrQB4FZ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 544, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ZVKR2IsBoHnPTWrQCIG7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 545, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'ZlKR2IsBoHnPTWrQCoEt', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 546, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'Z1KR2IsBoHnPTWrQC4GM', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 547, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'aFKR2IsBoHnPTWrQDIH5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 548, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'aVKR2IsBoHnPTWrQDoFM', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 549, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'alKR2IsBoHnPTWrQD4Gt', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 550, '_primary_term': 1}
# {'_index': 'semantic-index', '_id': 'a1KR2IsBoHnPTWrQEYEQ', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 551, '_primary_term': 1}

# %% [markdown]
# ---
# ## 1. キーワード検索

# %%
question = "EC2で起動できるOSは何ですか？"

# %%
from langchain.chat_models import BedrockChat

llm = BedrockChat(model_id="anthropic.claude-instant-v1", model_kwargs={"max_tokens_to_sample": 4000})

# %%
from typing import Any, Iterable, List

from langchain.callbacks.manager import CallbackManagerForRetrieverRun
from langchain.docstore.document import Document
from langchain.schema import BaseRetriever

class OpenSearchBM25Retriever(BaseRetriever):

    client: Any
    index_name: str

    def _get_relevant_documents(
        self, query: str, *, run_manager: CallbackManagerForRetrieverRun
    ) -> List[Document]:

        body = {
            "_source": {
                "excludes": [
                    "passage_embedding"
                ]
            },
            "query": {
                "match": {
                    "question": {
                        "query": query
                    }
                }
            }
        }

        res  = self.client.search(index=index_name,body=body)

        docs = []
        for r in res["hits"]["hits"]:
            docs.append(Document(page_content=r["_source"]["answer"]))
        return docs


bm25_retriever = OpenSearchBM25Retriever(client=client, index_name=index_name)

bm25_retriever.get_relevant_documents(question)
# Out:
# [Document(page_content='Q: Amazon EC2 で何ができますか?\nAmazon Simple Storage Service (Amazon S3) がクラウド内のストレージを可能とするのとまったく同様に、Amazon EC2 は、クラウド内での「コンピューティング」を可能にします。\xa0 Amazon EC2 のシンプルなウェブサービスインターフェイスによって、手間をかけず、必要な機能を取得および設定できます。お客様のコンピューティングリソースに対して、高機能なコントロールが提供され、Amazon の実績あるインフラストラクチャ上で実行できます。Amazon EC2 では、わずか数分間で新規サーバーインスタンスを取得して起動できるようになります。これにより、コンピューティング要件の変化に合わせて、すばやく容量をスケールアップおよびスケールダウンできます。実際に使用した分のみ料金が発生するため、Amazon EC2 はコンピューティングの経済性も変革します。'),
#  Document(page_content='Q:Nitro Hypervisor では、インスタンスの再起動と終了の EC2 API リクエストがどのように実装されますか?\nNitro Hypervisor は、インスタンスで実行されているオペレーティングシステムに、業界標準の ACPI メソッドによって正常にシャットダウンする必要があることを通知します。ただし、Linux インスタンスの場合は、acpid がインストールされており、正常に機能している必要があります。インスタンスで acpid が機能していない場合、終了イベントは数分間遅れ、ハードリセットまたは電源オフとして実行されます。'),
#  Document(page_content='Q:「EC2 コンピューティングユニット (ECU)」とは何ですか? またそれを導入する理由は何ですか?\nユーティリティコンピューティングモデルへの移行は、デベロッパーが CPU リソースに対してこれまで持っていた考え方を根本的に変えるものです。特定のプロセッサを購入またはリースして数か月から数年間使用する代わりに、時間単位で処理能力をレンタルすることができます。Amazon EC2 は、コモディティなハードウェア上に構築されているため、EC2 インスタンスが内在する物理的なハードウェアの種類は、時間と共に異なる可能性があります。当社の目的は、実際に利用するハードウェアがどのようなものであろうと、一定量の CPU 能力を安定したかたちで供給することです。\nAmazon EC2 は様々な手段を使用し、各インスタンスに安定した期待通りの CPU 能力を提供します。異なるインスタンスタイプ間でデベロッパーが簡単に CPU 能力値を比較できるように、Amazon EC2 コンピュートユニット (ECU) が定義されています。特定のインスタンスに配分されている CPU 量は、これらの EC2 コンピュートユニットで明示されます。当社はいくつかのベンチマークとテストを使用して、EC2 コンピュートユニットのパフォーマンスの安定性と予測可能性を管理します。EC2 コンピューティングユニット (ECU) は、Amazon EC2 インスタンスの整数処理能力を相対的に測定します。将来的に、コンピューティング性能についてお客様により明確な図を提供するメトリクスが見つかった場合には、EC2 コンピュートユニット (ECU) の定義方法が追加または交換される場合があります。'),
#  Document(page_content='Q: Amazon EC2 Fleet とは何ですか?\nEC2 Fleet では単一の API コールで、さまざまなインスタンスタイプ、アベイラビリティーゾーン、およびオンデマンド、リザーブドインスタンス (RI)、スポットインスタンスの購入モデルにわたってコンピューティングキャパシティをプロビジョニングして、スケール、パフォーマンス、コストを最適化できます。'),
#  Document(page_content='Q: OS とソフトウェアのアップデートを Apple Update Servers から直接 Mac インスタンスに適用できますか?\nEC2 Mac インスタンスでは、macOS ソフトウェアの自動アップデートは無効になっています。必要なバージョンの macOS を起動するために、公式に提供されている macOS AMI を使用することをお勧めします。x86 ベースの EC2 Mac インスタンスでは、ソフトウェアアップデート環境設定ペイン、またはソフトウェアアップデート CLI コマンドで macOS のバージョンをアップデートできます。現時点では、EC2 M1 Mac インスタンスでの macOS アップデートはサポートしていません。どちらの EC2 Mac インスタンスでも、アプリケーションやその他のユーザースペースのソフトウェアをインストールおよびアップデートすることができます。'),
#  Document(page_content='Q: Amazon EC2 X2gd インスタンスとは何ですか?\nAmazon EC2 X2gd インスタンスは、AWS が設計した Arm ベースの AWS Graviton2 プロセッサを搭載した次世代のメモリ最適化インスタンスです。X2gd インスタンスは、x86 ベースの X1 インスタンスと比較して最大 55% 優れたコストパフォーマンスを提供し、Amazon EC2 のメモリの GiB あたりのコストを最小限に抑えます。\xa0これらは、専有ハードウェアと Nitro Hypervisor の組み合わせである AWS Nitro System 上に構築された X インスタンスの最初のインスタンスです。'),
#  Document(page_content='Q: EC2 UltraClusters とは何ですか? どうすればアクセスできますか?\nP4d インスタンスは、EC2 UltraCluster と呼ばれるハイパースケールクラスターにデプロイされます。それぞれの EC2 UltraCluster は、4,000 を超える NVIDIA A100 Tensor Core GPU、ペタビット規模のネットワーキング、FSx for Lustre による拡張可能な低レイテンシーストレージで構成されています。それぞれの EC2 UltraCluster が、世界トップクラスのスーパーコンピューターの 1 つということになります。EC2 SuperCluster では、簡単に P4d インスタンスを起動できます。さらに支援が必要な場合は、お問い合わせください。'),
#  Document(page_content='Q: Amazon EC2 F1 とは何ですか?\nAmazon EC2 F1 は、アプリケーションの高速化に利用できる、プログラミング可能なハードウェアによるコンピューティングインスタンスです。新しい F1 インスタンスタイプは高いパフォーマンスが得られ、FPGA にアクセスしてカスタムハードウェア高速化の開発とデプロイが容易に行えます。'),
#  Document(page_content='Q: EC2 High Memory インスタンスとは何ですか?\nAmazon EC2 High Memory インスタンスは、単一インスタンスの 3 TiB、6 TiB、9 TiB、12 TiB、18 TiB、および 24 TiB のメモリを提供します。これらのインスタンスは、クラウド内の SAP HANA 製品のインストレーションを含むラージインメモリデータベースを実行するように設計されています。 \nEC2 High Memory インスタンスは 8 ソケットのプラットフォームを使用した 3 TiB、6 TiB、9 TiB、12 TiB のメモリを持つインスタンスで、Intel® Xeon® Platinum 8176M (Skylake) プロセッサを採用しています。18 TiB および 24 TiB のメモリを持つ EC2 High Memory インスタンスは、8 ソケットのプラットフォームを使用した最初の Amazon EC2 インスタンスで、ミッションクリティカルエンタープライズワークロードを最適化した第二世代の Intel® Xeon® Scalable (Cascade Lake) プロセッサーを採用しています。EC2 High Memory インスタンスは Amazon Elastic Network Adapter (ENA) に基づいた最大 100 Gbps の総合ネットワーク帯域幅での強化ネットワークを使用して高いネットワークスループットと低いレイテンシーを実現しています。EC2 High Memory インスタンスは、デフォルトで EBS 最適化されており、暗号化および非暗号化の EBS ボリュームをサポートします。'),
#  Document(page_content='Q: Amazon EC2 Mac インスタンスとは何ですか?\nAmazon EC2 Mac インスタンスにより、お客様は、クラウドでオンデマンドの macOS ワークロードを初めて実行できるようになり、すべての Apple デベロッパーが AWS の柔軟性、スケーラビリティ、およびコストメリットの恩恵を受けることができます。EC2 Mac インスタンスを使用すると、iPhone、iPad、Mac、Apple Watch、Apple TV、および Safari 用のアプリを作成するデベロッパーは、macOS 環境を数分でプロビジョニングしてアクセスし、必要に応じて容量を動的にスケールし、AWS の従量制料金の利点を享受できます。')]

# %%
from langchain.chains import ConversationalRetrievalChain

bm25_qa = ConversationalRetrievalChain.from_llm(
  llm, 
  retriever=bm25_retriever
  )

bm25_response = bm25_qa({"question": question, "chat_history": [] })

# %%
print(bm25_response['answer'])
# Out:
#  Amazon EC2では、以下のような主なOSが起動できます。
#
# - Linux固定AMI(Amazon Linux、Ubuntu、CentOSなど)
# - Windowsサーバー
# - FreeBSD
# - Oracle Linux
# - SUSE Linux
# - Red Hat Enterprise Linux (RHEL)
# - macOS
# - Other Linux distributions
#
# EC2では、これらの主要OSに加えて、ユーザが独自に作成したカスタムAMIからの起動も可能です。AMI(Amazon Machine Image)は仮想マシンのスナップショットで、任意のOSとソフトウェアをプレロードできるため、ユーザの要件に合わせたカスタムOS/ソフトウェア構成のEC2インスタンスを起動できます。

# %% [markdown]
# ---
# ## 2. ニューラル検索

# %%
from typing import Any, Iterable, List

from langchain.callbacks.manager import CallbackManagerForRetrieverRun
from langchain.docstore.document import Document
from langchain.schema import BaseRetriever

class OpenSearchNeuralRetriever(BaseRetriever):

    client: Any
    index_name: str
    model_id: str

    def _get_relevant_documents(
        self, query: str, *, run_manager: CallbackManagerForRetrieverRun
    ) -> List[Document]:

        body = {
            "_source": {
                "excludes": [
                    "passage_embedding"
                ]
            },
            "query": {
                "neural": {
                    embedding_field: {
                        "query_text": question,
                        "model_id": self.model_id,
                    }
                }
            }
        }

        res  = self.client.search(index=index_name,body=body)

        docs = []
        for r in res["hits"]["hits"]:
            docs.append(Document(page_content=r["_source"]["answer"]))
        return docs


neural_retriever = OpenSearchNeuralRetriever(client=client, index_name=index_name, model_id=model_id)

neural_retriever.get_relevant_documents(question)
# Out:
# [Document(page_content='Q: どうすれば Amazon EC2 の使用を開始できますか?\nAmazon EC2 にサインアップするには、Amazon EC2 詳細ページ上の [このウェブサービスにサインアップ] ボタンを選択します。このサービスにアクセスするには、AWS のアカウントを保有している必要があります。これをまだ持っていない場合は、Amazon EC2 サインアッププロセスの開始時に、プロンプト画面が表示されてこれを作成することができます。サインアップの後、Amazon EC2 ドキュメントをご参照ください。ここには開始方法に関するガイドが含まれています。'),
#  Document(page_content='Q: 既存の Windows Server ライセンスを EC2 で使用できますか?\nはい、できます。ImportImage ツールを使用して自分の Windows Server マシンイメージをインポートした後、それらのマシンイメージから EC2 Dedicated Hosts にインスタンスを起動して、インスタンスを効果的に管理し、使用量をレポートすることができます。通常、Microsoft はソケットやコアなどの物理リソースに応じてライセンス使用量を追跡するように要求しますが、Dedicated Hosts を使用するとそれが簡単に行えます。自分の Windows Server ライセンスを Amazon EC2 Dedicated Hosts で使用する方法について詳しくは Dedicated Hosts の詳細に関するページを参照してください。'),
#  Document(page_content='Q: EC2 Mac インスタンスで EC2 ユーザーデータを使用するにはどうすればよいですか?\nEC2 Linux および Windows インスタンスと同様に、EC2 Mac インスタンスにカスタムユーザーデータを渡すことができます。EC2 Mac インスタンスは、cloud-init の代わりに、オープンソースの起動デーモンである ec2-macos-init を使用します。お客様はこのデータを EC2 Launch Wizard に、プレーンテキスト、ファイル、または Base64 エンコードテキストとして渡すことができます。'),
#  Document(page_content='Q: Amazon EC2 環境でシステムを稼動させるにはどうすればよいですか?\nアカウントをセットアップして AMI を選択または作成すると、インスタンスを起動する準備が整います。RunInstances API コールを使用して、任意の数のオンデマンドインスタンス上で AMI を開始できます。起動したいインスタンス数を明示するだけで完了します。\xa0ご使用のオンデマンドのクォータを超えて実行したい場合は、「Amazon EC2 インスタンス申請フォーム」をご提出ください。\nAmazon EC2 でリクエストが対応可能な場合、RunInstances で要求されたインスタンスの起動が開始されます。DescribeInstances API コールを使用して、インスタンスのステータスについて確認できます。また、TerminateInstances API 呼び出しを使用して、任意の数のインスタンスをプログラム的に終了することもできます。\nAmazon EBS ブートパーティションを使用してインスタンスを実行中の場合は、StopInstances API コールを使用して、コンピュートリソースを解放しつつ、ブートパーティション上でデータを格納することもできます。Amazon EBS ブートパーティションで関連インスタンスの再起動の準備が整ったら、StartInstances API を使用できます。\nさらに、お客様のアプリケーション利用時間が調整可能なものであれば、スポットインスタンスを使用して利用コストをさらに削減することもできます。スポットインスタンスの利用方法に、詳細な説明が記載されていますので、ぜひご覧ください。\nご希望であれば、AWS マネジメントコンソール または当社のコマンドラインツールを使用したコマンドラインで、これらすべてのアクションを実行することもできます。これらの機能は、このウェブサービス API に実装されています。'),
#  Document(page_content='Q: 仮想マシンを Amazon EC2 インスタンスにインポートするにはどうすればよいですか?\nAmazon EC2 API ツールを使用して VM イメージをインポートすることができます。\n\nec2-import-instance API 経由で、VMDK、VHD、または RAW ファイルをインポートします。インスタンスのインポートタスクでは、Amazon EC2 インスタンスのプロパティ (インスタンスのサイズ、アベイラビリティーゾーン、セキュリティグループ) を適切に設定するために必要なパラメータがキャプチャされ、ディスクイメージが Amazon S3 にアップロードされます。\nアップロードが完了する前に ec2-import-instance が中断または終了した場合は、ec2-resume-import を使ってアップロードを再開します。インポートタスクは、それが中断されたところから再開されます。\nec2-describe-conversion-tasks コマンドを使って、インポートの進行を監視し、結果として出た Amazon EC2 インスタンス ID を取得します。\nインポートタスクが完了すると、ec2-run-instances API にそのインスタンス ID を指定することにより、Amazon EC2 インスタンスを起動することができます。\n最後に、ec2-delete-disk-image コマンドラインツールを使用してディスクイメージを Amazon S3 から削除します (これ以降は不要のため)。 \n\nまたは、VMware vSphere 仮想化プラットフォームを使用する場合は、AWS Management Portal for vCenter が提供するグラフィカルなユーザーインターフェイスを使用して、仮想マシンを Amazon EC2 にインポートできます。AWS Management Portal for vCenter の開始方法に関するガイドを参照してください。AWS Management Portal for vCenter には、VM Import の統合サポートがあります。ポータルが vCenter 内にインストールされたら、[VM] を右クリックし、[Migrate to EC2] を選択して VM から EC2 インスタンスを作成します。ポータルがユーザーに代わって、vCenter から VM をエクスポートし、S3 にアップロードし、EC2 インスタンスに変換させる処理を行います。追加の操作も必要ありません。さらに、ポータル内で VM の移行の進行状況を追跡できます。'),
#  Document(page_content='Q: Amazon EC2 ではいくつのインスタンスを実行できますか?\nvCPU ベースのオンデマンドインスタンスの制限ごとにオンデマンドインスタンスを実行すること、20 個のリザーブドインスタンスを購入すること、1 つのリージョンにつき動的スポット制限ごとにスポットインスタンスをリクエストすることという制限があります。新規の AWS アカウントでは、当初この上限よりも少ない数に制限されることがあります。 \n\n\nそれを超えるインスタンスを必要とする場合は、お客様のユースケースを含めて「Amazon EC2 上限引き上げ申請フォーム」にご記入ください。上限の引き上げを検討いたします。上限の引き上げは、申請されたリージョンに限定されます。'),
#  Document(page_content='Q:マイクロインスタンスで Amazon EC2 のすべての特徴を利用できますか?\n現在、マイクロインスタンスでは Amazon DevPay をご利用いただけません。 \n\n\n\n\n\n\n\n Nitro Hypervisor'),
#  Document(page_content='Q: Amazon EC2 は 2 つ以上の AWS リージョンで稼動しますか?\nはい。Amazon の製品およびサービスがリージョンごとに提供されているかの詳細については、製品およびサービス一覧 (リージョン別) を参照してください。'),
#  Document(page_content='Q: Amazon EC2 で何ができますか?\nAmazon Simple Storage Service (Amazon S3) がクラウド内のストレージを可能とするのとまったく同様に、Amazon EC2 は、クラウド内での「コンピューティング」を可能にします。\xa0 Amazon EC2 のシンプルなウェブサービスインターフェイスによって、手間をかけず、必要な機能を取得および設定できます。お客様のコンピューティングリソースに対して、高機能なコントロールが提供され、Amazon の実績あるインフラストラクチャ上で実行できます。Amazon EC2 では、わずか数分間で新規サーバーインスタンスを取得して起動できるようになります。これにより、コンピューティング要件の変化に合わせて、すばやく容量をスケールアップおよびスケールダウンできます。実際に使用した分のみ料金が発生するため、Amazon EC2 はコンピューティングの経済性も変革します。'),
#  Document(page_content='Q: 各リージョンで利用できる Amazon EC2 インスタンスタイプを教えてください。\n利用できるすべてのインスタンスおよびリージョンのリストについては、Amazon EC2 の料金を参照してください。\n\n\n\n\n\n\n\n マイクロインスタンス')]

# %%
from langchain.chains import ConversationalRetrievalChain

neural_qa = ConversationalRetrievalChain.from_llm(
  llm, 
  retriever=neural_retriever
  )

neural_response = neural_qa({"question": question, "chat_history": [] })

# %%
print(neural_response['answer'])
# Out:
#  Amazon EC2で起動できる主なOSは以下のとおりです。
#
# - Linux各ディストリビューション(Amazon Linux、Ubuntu、CentOSなど)
# - Windows Server(Windows Server 2022など)
# - VMware ESXi
# - Oracle Linux
# - SUSE Linux
# - Red Hat Enterprise Linux
# - FreeBSD
# - Oracle Solaris
# - Apache Mavericks
#
# EC2上で新しいOSイメージ(AMI)を作成することも可能で、独自の環境やアプリケーションを配備できます。
#
# 主な技術的な制約は以下の通りです。
#
# - 64ビットアーキテクチャのOSのみサポート
# - グラフィカルなデスクトップ環境はサポートされない
# - 特定のEC2インスタンスタイプではサポートされないOSがある
#
# 具体的なEC2でサポートされているAMIのリストはAWSのサイト内のドキュメントを確認する必要があります。如何なるOSでも実行できる訳ではありませんが、一般的なLinuxディストリビューションやWindowsサーバオペレーティングシステムは多くのEC2インスタンスタイプで実行可能です。

# %% [markdown]
# ---
# ## 3. ハイブリッド検索

# %%
from typing import Any, Iterable, List

from langchain.callbacks.manager import CallbackManagerForRetrieverRun
from langchain.docstore.document import Document
from langchain.schema import BaseRetriever

class OpenSearchHybridRetriever(BaseRetriever):

    client: Any
    index_name: str
    model_id: str

    def _get_relevant_documents(
        self, query: str, *, run_manager: CallbackManagerForRetrieverRun
    ) -> List[Document]:

        body = {
            "_source": {
                "excludes": [
                    "passage_embedding"
                ]
            },
            "query": {
                "hybrid": {
                    "queries": [
                        {
                            "match": {
                                "question": {
                                    "query": question
                                }
                            }
                        },
                        {
                            "neural": {
                                "passage_embedding": {
                                    "query_text": question,
                                    "model_id": model_id,
                                }
                            }
                        }
                    ]
                }
            }
        }

        res  = self.client.search(index=index_name,body=body)

        docs = []
        for r in res["hits"]["hits"]:
            docs.append(Document(page_content=r["_source"]["answer"]))
        return docs


hybrid_retriever = OpenSearchHybridRetriever(client=client, index_name=index_name, model_id=model_id)

hybrid_retriever.get_relevant_documents(question)
# Out:
# [Document(page_content='Q: Amazon EC2 で何ができますか?\nAmazon Simple Storage Service (Amazon S3) がクラウド内のストレージを可能とするのとまったく同様に、Amazon EC2 は、クラウド内での「コンピューティング」を可能にします。\xa0 Amazon EC2 のシンプルなウェブサービスインターフェイスによって、手間をかけず、必要な機能を取得および設定できます。お客様のコンピューティングリソースに対して、高機能なコントロールが提供され、Amazon の実績あるインフラストラクチャ上で実行できます。Amazon EC2 では、わずか数分間で新規サーバーインスタンスを取得して起動できるようになります。これにより、コンピューティング要件の変化に合わせて、すばやく容量をスケールアップおよびスケールダウンできます。実際に使用した分のみ料金が発生するため、Amazon EC2 はコンピューティングの経済性も変革します。'),
#  Document(page_content='Q: Amazon EC2 で何ができますか?\nAmazon Simple Storage Service (Amazon S3) がクラウド内のストレージを可能とするのとまったく同様に、Amazon EC2 は、クラウド内での「コンピューティング」を可能にします。\xa0 Amazon EC2 のシンプルなウェブサービスインターフェイスによって、手間をかけず、必要な機能を取得および設定できます。お客様のコンピューティングリソースに対して、高機能なコントロールが提供され、Amazon の実績あるインフラストラクチャ上で実行できます。Amazon EC2 では、わずか数分間で新規サーバーインスタンスを取得して起動できるようになります。これにより、コンピューティング要件の変化に合わせて、すばやく容量をスケールアップおよびスケールダウンできます。実際に使用した分のみ料金が発生するため、Amazon EC2 はコンピューティングの経済性も変革します。'),
#  Document(page_content='Q: Amazon EC2 で何ができますか?\nAmazon Simple Storage Service (Amazon S3) がクラウド内のストレージを可能とするのとまったく同様に、Amazon EC2 は、クラウド内での「コンピューティング」を可能にします。\xa0 Amazon EC2 のシンプルなウェブサービスインターフェイスによって、手間をかけず、必要な機能を取得および設定できます。お客様のコンピューティングリソースに対して、高機能なコントロールが提供され、Amazon の実績あるインフラストラクチャ上で実行できます。Amazon EC2 では、わずか数分間で新規サーバーインスタンスを取得して起動できるようになります。これにより、コンピューティング要件の変化に合わせて、すばやく容量をスケールアップおよびスケールダウンできます。実際に使用した分のみ料金が発生するため、Amazon EC2 はコンピューティングの経済性も変革します。'),
#  Document(page_content='Q:Nitro Hypervisor では、インスタンスの再起動と終了の EC2 API リクエストがどのように実装されますか?\nNitro Hypervisor は、インスタンスで実行されているオペレーティングシステムに、業界標準の ACPI メソッドによって正常にシャットダウンする必要があることを通知します。ただし、Linux インスタンスの場合は、acpid がインストールされており、正常に機能している必要があります。インスタンスで acpid が機能していない場合、終了イベントは数分間遅れ、ハードリセットまたは電源オフとして実行されます。'),
#  Document(page_content='Q:「EC2 コンピューティングユニット (ECU)」とは何ですか? またそれを導入する理由は何ですか?\nユーティリティコンピューティングモデルへの移行は、デベロッパーが CPU リソースに対してこれまで持っていた考え方を根本的に変えるものです。特定のプロセッサを購入またはリースして数か月から数年間使用する代わりに、時間単位で処理能力をレンタルすることができます。Amazon EC2 は、コモディティなハードウェア上に構築されているため、EC2 インスタンスが内在する物理的なハードウェアの種類は、時間と共に異なる可能性があります。当社の目的は、実際に利用するハードウェアがどのようなものであろうと、一定量の CPU 能力を安定したかたちで供給することです。\nAmazon EC2 は様々な手段を使用し、各インスタンスに安定した期待通りの CPU 能力を提供します。異なるインスタンスタイプ間でデベロッパーが簡単に CPU 能力値を比較できるように、Amazon EC2 コンピュートユニット (ECU) が定義されています。特定のインスタンスに配分されている CPU 量は、これらの EC2 コンピュートユニットで明示されます。当社はいくつかのベンチマークとテストを使用して、EC2 コンピュートユニットのパフォーマンスの安定性と予測可能性を管理します。EC2 コンピューティングユニット (ECU) は、Amazon EC2 インスタンスの整数処理能力を相対的に測定します。将来的に、コンピューティング性能についてお客様により明確な図を提供するメトリクスが見つかった場合には、EC2 コンピュートユニット (ECU) の定義方法が追加または交換される場合があります。'),
#  Document(page_content='Q: Amazon EC2 Fleet とは何ですか?\nEC2 Fleet では単一の API コールで、さまざまなインスタンスタイプ、アベイラビリティーゾーン、およびオンデマンド、リザーブドインスタンス (RI)、スポットインスタンスの購入モデルにわたってコンピューティングキャパシティをプロビジョニングして、スケール、パフォーマンス、コストを最適化できます。'),
#  Document(page_content='Q: OS とソフトウェアのアップデートを Apple Update Servers から直接 Mac インスタンスに適用できますか?\nEC2 Mac インスタンスでは、macOS ソフトウェアの自動アップデートは無効になっています。必要なバージョンの macOS を起動するために、公式に提供されている macOS AMI を使用することをお勧めします。x86 ベースの EC2 Mac インスタンスでは、ソフトウェアアップデート環境設定ペイン、またはソフトウェアアップデート CLI コマンドで macOS のバージョンをアップデートできます。現時点では、EC2 M1 Mac インスタンスでの macOS アップデートはサポートしていません。どちらの EC2 Mac インスタンスでも、アプリケーションやその他のユーザースペースのソフトウェアをインストールおよびアップデートすることができます。'),
#  Document(page_content='Q: Amazon EC2 X2gd インスタンスとは何ですか?\nAmazon EC2 X2gd インスタンスは、AWS が設計した Arm ベースの AWS Graviton2 プロセッサを搭載した次世代のメモリ最適化インスタンスです。X2gd インスタンスは、x86 ベースの X1 インスタンスと比較して最大 55% 優れたコストパフォーマンスを提供し、Amazon EC2 のメモリの GiB あたりのコストを最小限に抑えます。\xa0これらは、専有ハードウェアと Nitro Hypervisor の組み合わせである AWS Nitro System 上に構築された X インスタンスの最初のインスタンスです。'),
#  Document(page_content='Q: EC2 UltraClusters とは何ですか? どうすればアクセスできますか?\nP4d インスタンスは、EC2 UltraCluster と呼ばれるハイパースケールクラスターにデプロイされます。それぞれの EC2 UltraCluster は、4,000 を超える NVIDIA A100 Tensor Core GPU、ペタビット規模のネットワーキング、FSx for Lustre による拡張可能な低レイテンシーストレージで構成されています。それぞれの EC2 UltraCluster が、世界トップクラスのスーパーコンピューターの 1 つということになります。EC2 SuperCluster では、簡単に P4d インスタンスを起動できます。さらに支援が必要な場合は、お問い合わせください。'),
#  Document(page_content='Q: Amazon EC2 F1 とは何ですか?\nAmazon EC2 F1 は、アプリケーションの高速化に利用できる、プログラミング可能なハードウェアによるコンピューティングインスタンスです。新しい F1 インスタンスタイプは高いパフォーマンスが得られ、FPGA にアクセスしてカスタムハードウェア高速化の開発とデプロイが容易に行えます。')]

# %%
from langchain.chains import ConversationalRetrievalChain

hybrid_qa = ConversationalRetrievalChain.from_llm(
  llm, 
  retriever=hybrid_retriever
  )

hybrid_response = hybrid_qa({"question": question, "chat_history": [] })

# %%
print(hybrid_response['answer'])
# Out:
#  Amazon EC2では、主要なオペレーティングシステムがサポートされています。
#
# - Linuxおよびそのディストリビューション(Amazon Linux、Ubuntu、CentOSなど)
#
# - Windows Server
#
# - FreeBSD
#
# - Oracle Linux
#
# - Redis Enterprise Flash Storage
#
# - SUSE Linux
#
# - VMware ESXi
#
# - Citrix XenServer
#
# 以上がEC2で起動可能な主要なオペレーティングシステムです。Linuxディストリビューションが最も幅広くサポートされており、WindowsServerや一部のUnix系OSもサポートされています。EC2では様々なOSから選択できるため、お客様の必要なOS環境でサービスを拡張できます。

# %% [markdown]
# ---
# いろいろ試す
# ---

# %%
questions = [
  "EC2でMacOSは起動できますか？",
  "EC2の優れた点を教えてください。",
  "EC2とコンテナの違いを教えて"
]

for q in questions:
  print("=====")
  print(q)
  print("-----BM25-----")
  res = bm25_qa({"question": q, "chat_history": [] })
  print(res['answer'])
  print("-----")
  print("-----Neural-----")
  res = neural_qa({"question": q, "chat_history": [] })
  print(res['answer'])
  print("-----")
  print("-----Hybrid-----")
  res = hybrid_qa({"question": q, "chat_history": [] })
  print(res['answer'])
  print("-----")
  print("-----")
# Out:
# =====
# EC2でMacOSは起動できますか？
# -----BM25-----
#  はい、EC2(Amazon Elastic Compute Cloud)ではMacOSを実行できるインスタンスタイプが用意されています。
#
# EC2にはEC2 Macインスタンスという、Mac miniハードウェアをベースとしたインスタンスタイプがあります。このインスタンスタイプではMacOSが起動・実行可能です。
#
# 現在提供されているEC2 Macインスタンスは主に2つあります:
#
# - x86アーキテクチャベースのEC2 Macインスタンス: Mac mini(Late 2018)がベースで、MacOS Mojaveが起動できます。
#
# - M1アーキテクチャベースのEC2 Macインスタンス: Mac mini(2020)がベースで、MacOS Big Surが起動できます。
#
# このようにEC2では物理的なMacハードウェアを利用したEC2 Macインスタンスを通じて、MacOSの実行がサポートされています。
# -----
# -----Neural-----
#  はい、Amazon EC2ではMacOSの仮想マシン(VM)を起動できます。
#
# Amazon EC2 for Macについての主な点は以下のとおりです:
#
# - EC2 for Macは、Mac mini仮想マシンとして提供されています。MacOS High Sierra(10.13)やMacOS Mojave(10.14)がサポートされています。
#
# - EC2 for Macインスタンスはオンデマンドおよびスポットインスタンスとして利用可能です。
#
# - CPU、メモリ、ストレージの構成はEC2の他のインスタンスタイプと同様にカスタマイズ可能です。
#
# - MacOS VMは専用か共有のサーバーホスト上で実行され、専用ホストの場合は他の顧客インスタンスとの影響を受けません。
#
# - 安定性、セキュリティ、スケーラビリティがAWSのインフラによってサポートされます。
#
# - EC2 for Macは開発、テスト、デプロイといった用途で使用されています。
#
# 以上の通り、EC2ではMacOS VMを簡単に起動し、クラウドのメリッツをMacOS環境でも利用できるようになっています。
# -----
# -----Hybrid-----
#  はい、Amazon EC2ではMacOSの仮想マシン(インスタンス)を起動することができます。
#
# Amazon EC2 for Macでは、Mac Mini仮想マシン(インスタンス)としてMacOSをクラウド上で実行できます。IntelベースやApple Silicon(M1)ベースのMacOSエイミを利用してインスタンスを起動できます。
#
#  EC2 for Macでは、MacOSのインストール、設定、管理を簡単に行うことができ、クラウド上でMacアプリケーションの開発やテストなどに利用できます。通常のEC2インスタンス同様に、オンデマンドやスポットインスタンスといったユーザームードでMacOSマシンを起動可能です。
#
# 以上の通り、Amazon EC2環境ではMacOSの仮想マシン(インスタンス)を起動することが支援されています。
# -----
# -----
# =====
# EC2の優れた点を教えてください。
# -----BM25-----
#  Amazon EC2の主な優れた点は以下の通りです。
#
# - 様々なインスタンスタイプから選択できるので、必要なコンピューティングリソースや機能がサポートされています。
#
# - 世界中の広範なアベイラビリティゾーンとリージョンから選択でき、事業継続性と障害復旧性を高められます。
#
# - 自動スケーリング機能でコストを抑えながら性能を最大限に引き出せます。
#
# - 安定した高性能コンピューティングエンジンをオンデマンドで利用でき、キャパシティプランニング不要です。
#
# - 消費量に応じた課金なのでオーバプロvisioning不要でコスト効率が高いです。
#
# - 豊富な機能セット(EBS、EFS、エラストィックインターネット・ゲートウェイなど)が組み合わせて利用可能です。
#
# - 北米、南米、アジア、欧州、中東、アフリカの広域で展開されており、グローバルなシステム構築が実現できます。
#
# 以上がAmazon EC2の主な優れた点だと思います。フレキシビリティと可用性が非常に高いクラウドコンピューティングサービスだと言えます。
# -----
# -----Neural-----
#  Amazon EC2の主な優れた点は以下の通りです。
#
# - 操作性が高い:インスタンスの起動/停止/削除などがAPIやコンソールから簡単に行える
#
# - 柔軟性が高い:需要に応じてインスタンスの数や種類をスケールアップ/ダウンできる
#
# - 安価性:実際に使用した分のみを課金するため、コストが抑えられる
#
# - 信頼性が高い:世界各地にあるアマゾンのインフラ基盤を活用できる
#
# - セキュリティが強固:未使用時のインスタンスは自動的にシャットダウンされる
#
# - 可用性が高い:全世界規模で分散したアベイラビリティゾーン構成
#
# - 管理が容易:コンソールやCLIから容易に管理・監視ができる
#
# - 性能が高速:専用ハードウェア(GPU等)を使用できるインスタンスもある
#
# - 様々なOSに対応:市場主流のOSに対応し、自由度が高い
#
# 以上がAmazon EC2の主な優れた点だと思います。需要追従型価格と大規模インフラを背景に、フレキシビリティとTCO面で優位性があります。
# -----
# -----Hybrid-----
#  Amazon EC2の代表的な優れた点は以下の点です:
#
# - 柔軟性が高い - 必要なリソース(CPU、メモリ、ストレージなど)をオンデマンドで調整できます。
#
# - スケーラビリティが高い - トラフィックや負荷が変動しても対応でき、必要に応じて容易にスケールアウト/インできます。
#
# - 安定性が高い - AWSの中心的なサービスの1つなのでアップタイムが極めて高く、信頼性が高いインフラを背景に支えられています。
#
# - コストパフォーマンスが高い - 実際に使用した分のみ課金となるため、コストを抑えながら必要な性能が取れます。
#
# - グローバルな展開が可能 - AWSの世界規模なインフラを活用でき、アプリケーションを簡単にグローバルに展開できます。
#
# - 管理が軽減される - 物理サーバの管理から解放され、自動化された管理インターフェイスを利用できます。
#
# 以上がAmazon EC2の主な優れた点だと思います。特にコストパフォーマンスとスケーラビリティの高さがAWSを選択する大きな理由だと考えられています。
# -----
# -----
# =====
# EC2とコンテナの違いを教えて
# -----BM25-----
#  EC2とコンテナの違いは以下の点です:
#
# - EC2は仮想マシン(VM)で、オペレーティングシステム(OS)が完全インストールされています。コンテナはOSのカーネルを共有しますが、アプリケーションとライブラリだけがインストールされます。
#
# - EC2は仮想マシンレベルのリソースを割り当てます。コンテナはアプリケーションレベルでリソースを共有します。
#
# - EC2はスタートアップが遅く、リソース使用量が多い傾向にあります。コンテナはスタートアップが速く、リソース使用量が少ないです。
#
# - EC2はアプリケーションデプロイ単位が1仮想マシンです。コンテナはアプリケーションデプロイ単位が1コンテナとなります。
#
# - EC2は仮想マシン単位でコスト計算します。コンテナは使用リソース量でコスト計算されます。
#
# 以上がEC2とコンテナの主な違いです。コンテナは軽量化と効率化が図れるため、微細グレインなアプリケーションに向いています。
# -----
# -----Neural-----
#  Amazon EC2とコンテナの主な違いは以下の通りです。
#
# - EC2は仮想マシン(VM)レベルで実行されます。コンテナはアプリケーションとライブラリのみから成り立ち、OSレベルではなくアプリケーションレベルで運用されます。
#
# - EC2は1インスタンス1OSです。コンテナでは複数のアプリケーションを1OS上で実行できます。
#
# - EC2の起動と停止に時間がかかります。コンテナは秒レベルで起動と停止が可能です。
#
# - EC2は仮想リソース全体を利用します。コンテナは必要なリソースだけを利用しますので、リソース利用効率が高い。
#
# - EC2は仮想マシンとして独立したシステムとして利用します。コンテナはアプリケーション中心で、共有OS上で複数アプリを分離実行します。
#
# - EC2にはストレージが内蔵されています。コンテナストレージは外部ボリュームに依存します。
#
# 以上の点から、EC2は長期・安定運用が目的で、コンテナはアジャイル開発・高密度実行が目的です。EC2とコンテナは目的に応じて利用されます。
# -----
# -----Hybrid-----
#  Amazon EC2とコンテナの主な違いは以下の点です:
#
# - EC2は仮想マシンの概念で、リソースを割り当てごとに完全なOS環境が提供されます。コンテナはアプリケーションごとにOSカーネルを共有し、リソース使用量が少ないです。
#
# - EC2インスタンスでは、仮想マシン単位でリソースが割り当てられます。コンテナはアプリケーション単位で動作し、必要なリソースだけを割り当てられます。
#
# - EC2はハードウェアレベルで分離された独立した環境を提供します。コンテナは同じOSカーネルを共有するため、ある意味で仮想化レベルが高くないです。
#
# - EC2では起動と終了がそれぞれのインスタンスに対して行われます。コンテナはアプリケーション起動単位でスケールアップ/ダウンが可能です。
#
# - EC2はサーバレスアプリでも用いられますが、コンテナはマイクロサービスアーキテクチャの基盤として利用されるケースが多いです。
#
# 以上のように、EC2は仮想マシンとして独立したエンバイロメントを提供する一方、コンテナはアプリケーション中心で効率的なリソース利用が可能です。目的や需要に合わせて適材適所で利用されます。
# -----
# -----
